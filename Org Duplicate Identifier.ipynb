# %%
import pandas as pd
import numpy as np
import math
from jellyfish import jaro_winkler
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np
from py_common_subseq import find_common_subsequences
import numbers
import time
from collections import Counter 
from fuzzywuzzy import fuzz

# %%
import io
import shutil

with io.open('recipients_reduced.csv', encoding='utf-8', errors='ignore') as source:
    with io.open('recipients_reduced_utf.csv', mode='w', encoding='utf-8') as target:
        shutil.copyfileobj(source,target)

# %%
start_time = time.time()
print "LOADING DATAFRAMES INTO MEMORY..."

df = pd.read_csv('RecipientTableUpdated_1.30.19_utf.csv',keep_default_na=False)

#<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#define column names
org_id = 'Recipient_ID'
org_name = 'RecipientName'
org_address1 = 'AddressLine1Txt'
org_city = 'CityNm'
org_state = 'StateAbbreviationCd'
org_zip = 'Zip'
org_web = 'WebsiteAddressTxt'

#set parameters
token_match_min = 2 # minimum number of matched tokens to be considered a match
token_limiter = .9996 # percent of non-single tokens to tokenize, where rare tokens are at the bottom and common at the top
name_weight = .75 #note that this is really .75 * 4 because there are 4 org name simularity metrics
state_weight = 1
zip_weight = 1
phone_weight = 1
composite_score_min = 3.5 #minimum composite match score to be considered a match
#<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<

df.rename(columns={org_id:'id',org_name:'org_name',org_address1:'address1',org_city:'city',org_state:'state',org_zip:'postal_code',org_web:'web'}, inplace=True)

print("dataframes loaded --- %s seconds ---" % (time.time() - start_time))
print ""

start_time = time.time()
print "PRE-PROCESSING: NORMALIZE STATES..."
#normalize state codes
state_lkup = pd.read_csv('state_lkup.csv',keep_default_na=False)

from collections import defaultdict
state_dict = defaultdict(list)
for state, acronym in zip(state_lkup.state.values,state_lkup.acronym.values):
    state_dict[state].append(acronym)

df.state = df.state.str.lower()
df.state = df.state.replace(state_dict)

print("states normalized --- %s seconds ---" % (time.time() - start_time))
print ""

#when you finish pre-processing, this step to split into left and right dataframes:
left_df = df.copy()
left_df.rename(columns={'org_name':'l_org_name','address1':'l_address1','city':'l_city','state':'l_state','postal_code':'l_postal_code','web':'l_web'}, inplace=True)
right_df = df.copy()
right_df.rename(columns={'org_name':'r_org_name','address1':'r_address1','city':'r_city','state':'r_state','postal_code':'r_postal_code','web':'r_web'}, inplace=True)

start_time = time.time()
print "CREATING DICTIONARY OF ALL UNIQUE TOKENS W INCLUDE FLAG..." #<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
   
# for the left dataset
left_tokenized_columns = [
    'l_org_name',
    #'l_acronym',
    #'l_alt_name',
    'l_address1',
    #'l_address2',
    'l_city', 
    'l_state', 
    'l_postal_code',
    'l_web' 
    #'l_phone'
]

# and right
right_tokenized_columns = [
    'r_org_name',
    #'r_acronym',
    #'r_alt_name',
    'r_address1',
    #'r_address2',
    'r_city', 
    'r_state', 
    'r_postal_code',
    'r_web' 
    #'r_phone'
]

# lowercase the name and split on spaces, remove non-alphanumeric chars
def tokenize_name(name):
    if isinstance(name, basestring) is True:
        clean_name = ''.join(c if c.isalnum() else ' ' for c in name)
        return clean_name.lower().split()
    else:
        return name

unique_tokens = [] #we treat state and zips differently because we want to include ALl state and zip tokens as these are unique

#<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<< add chosen unique columns here from each df
for word in left_df['l_state']:
    if isinstance(word, float) is False:
        unique_tokens.append(tokenize_name(str(word)))

for word in left_df['l_postal_code']:
    if isinstance(word, float) is False:
        unique_tokens.append(tokenize_name(str(word)))

#for word in left_df['l_acronym']:
#    if isinstance(word, float) is False:
#        unique_tokens.append(tokenize_name(str(word)))

#for word in left_df['l_phone']:
#    if isinstance(word, float) is False:
#        unique_tokens.append(tokenize_name(str(word)))
#<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
        
unique_flat_list = [item for sublist in unique_tokens for item in sublist]

#instantiate counter and use to count word frequencies in flat list
u_cnt = Counter()
for token in unique_flat_list:
    u_cnt[token] += 1
    
u_cnt_dict = dict(u_cnt) #convert to dictionary

unique_tokens_df = pd.DataFrame(u_cnt_dict.items(), columns=['token', 'count'])
unique_tokens_df = unique_tokens_df.sort_values(by='count')  #sorting by count so that we can take the first x% of tokens by rare frequency

unique_token_flag = []
for index, value in enumerate(unique_tokens_df['count']):
    if value == 1:
        unique_token_flag.append(0)  #for any tokens occuring only once, we exclude
    else:
        unique_token_flag.append(1)

unique_tokens_df['flag'] = unique_token_flag        
        
all_other_words = [] #creating a list of all words used in just ONE of the dfs in selected columns, for counting to determine rarity

for word in left_df['l_org_name']:
    if isinstance(word, float) is False:
        all_other_words.append(tokenize_name(str(word)))

#for word in left_df['l_alt_name']:
#    if isinstance(word, float) is False:
#        all_other_words.append(tokenize_name(str(word)))

for word in left_df['l_address1']:
    if isinstance(word, float) is False:
        all_other_words.append(tokenize_name(str(word)))

for word in left_df['l_city']:
    if isinstance(word, float) is False:
        all_other_words.append(tokenize_name(str(word)))

for word in left_df['l_web']:
    if isinstance(word, float) is False:
        all_other_words.append(tokenize_name(str(word)))
    
flat_list = [item for sublist in all_other_words for item in sublist] #flatten list so it can be counted
#new_tokens = list(set(flat_list) - set(unique_flat_list)) #getting a list of tokens which are NOT included in the first flat_list

#instantiate counter and use to count word frequencies in flat list
cnt = Counter()
for token in flat_list:
    cnt[token] += 1
    
cnt_dict = dict(cnt) #convert to dictionary

main_tokens_df = pd.DataFrame(cnt_dict.items(), columns=['token', 'count'])
main_tokens_df = main_tokens_df.sort_values(by='count')  #sorting by count so that we can take the first x% of tokens by rare frequency

main_token_flag = []
for index, value in enumerate(main_tokens_df['count']):
    if value == 1:
        main_token_flag.append(0)  #for any tokens occuring only once, we exclude
    elif index < int(main_tokens_df.shape[0] * token_limiter): #important line, we are cutting the top x% of frequently occuring tokens
        main_token_flag.append(1)
    else:
        main_token_flag.append(0)  #for the most common tokens, we exclude

main_tokens_df['flag'] = main_token_flag

all_tokens = pd.concat([unique_tokens_df, main_tokens_df])

all_tokens.drop('count',axis=1,inplace=True)
all_tokens['flag'] = all_tokens.flag.astype(int) #converting flags to int
tokens_dct = all_tokens.to_dict('split') #converting tokens_df to dictionary
tokens_dct=dict(tokens_dct['data']) #honestly can't remember why this works, something to do with conversion to dictionary

#preparing token_ids which will be used for joining left and right dfs
all_tokens.sort_values(by='flag',ascending=False,inplace=True)
all_tokens.drop_duplicates(subset='token',keep='first',inplace=True)
token_ids = all_tokens.index.get_level_values(0)
all_tokens['token_id'] = token_ids

all_tokens.drop('flag',axis=1,inplace=True)
all_tokens['token_id'] = all_tokens.token_id.astype(int)
token_id_dct = all_tokens.to_dict('split')
tokens_id_dct=dict(token_id_dct['data'])

print("token dictionary created --- %s seconds ---" % (time.time() - start_time))
print ""
                           
start_time = time.time()
print "TOKENIZING LEFT DATAFRAME..." #<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<

#NOTE: tokenizing the dataframes is the most computationally expensive part of this script.  

#tokenize left dataframe using CountVectorizer
vocabulary = np.array([w for w, b in tokens_dct.items() if b ==1]) #this works even without the ==1 and I don't know why
cv = CountVectorizer( vocabulary=vocabulary)

frame_list = []
for colname in left_tokenized_columns:
    tokenmapping = cv.fit_transform(left_df[colname])
    df_row, token_id = tokenmapping.nonzero()

    frame_list.append(pd.DataFrame(np.vstack([vocabulary[token_id], left_df['id'].values[df_row]]).T, columns = ['token', 'id']))

left_keyed = pd.concat(frame_list)

#append token_id to token as this will be more efficient to join with
left_token_ids = []
for token in left_keyed.token:
    left_token_ids.append(tokens_id_dct[token])

left_keyed['token_id'] = left_token_ids
left_keyed.set_index('token_id',inplace=True)
left_keyed.drop('token',axis=1,inplace=True)
    
print("left dataframe tokenized --- %s seconds ---" % (time.time() - start_time))
print ""

start_time = time.time()
print "TOKENIZING RIGHT DATAFRAME..." #<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<

#tokenize right dataframe
right_keyed = left_keyed.copy()
    
print("right dataframe tokenized --- %s seconds ---" % (time.time() - start_time))
print ""

start_time = time.time()
print "JOINING LEFT & RIGHT TOKEN KEYS..." #<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<

#join left and right token keys
joined = left_keyed.join(right_keyed, how='inner',lsuffix='_l',rsuffix='_r')

print("left & right token keys joined --- %s seconds ---" % (time.time() - start_time))
print ""

start_time = time.time()
print "GROUPING BY UNIQUE LEFT & RIGHT IDS & GETTING COUNT OF MATCHED TOKENS..." #<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<

#aggregate to get a count of unique id_l and id_r pairs based on joined tokens, which is used to assess match strength
aggregations = {
    'id_l': 'count'
}

keys_grouped = joined.groupby(by=['id_l', 'id_r']).agg(aggregations)
keys_grouped.rename(columns={'id_l':'id_l count'}, inplace=True)

print("keys grouped & counted --- %s seconds ---" % (time.time() - start_time))
print ""

start_time = time.time()
print "REDUCING DOWN TO SUFFICIENT MATCHES..." #<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<

#here we are reducing down to those match candidates which meet the minimum threshold of matched tokens
#and crucially, we are excluding any matches to SELF
matched_records = keys_grouped[keys_grouped['id_l count'] >= token_match_min]

#adding a column for the id_r values, which are initially excluded becuase we are merging using the id_l
right_ids = matched_records.index.get_level_values('id_r')
matched_records['id_r'] = right_ids

#adding left Ids because I think we need them, probably a way to check index but meh
left_ids = matched_records.index.get_level_values('id_l')
matched_records['id_l'] = left_ids

duplicate_candidates = matched_records[matched_records['id_l'] <> matched_records['id_r']]

print("matches reduced --- %s seconds ---" % (time.time() - start_time))
print ""

start_time = time.time()
print "CONCATENATING MATCH IDS WITH ORIGINAL DATA..." #<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<

#renaming ids to be linked to source.  this happens here and not the beginning so as to play nice with the prepare join keys generator
left_df.rename(columns={'id':'id_l'}, inplace=True)
right_df.rename(columns={'id':'id_r'}, inplace=True)

#creating left/right dataframes which contain only the most relevant details for reviewing the match strengths
left_match_data = left_df[['id_l','l_org_name','l_city','l_state','l_postal_code','l_web']].copy()
right_match_data = right_df[['id_r','r_org_name','r_city','r_state','r_postal_code','r_web']].copy()

#making sure keys are str, results in blank df otherwise
left_match_data.id_l = left_match_data.id_l.astype('str')
right_match_data.id_r = right_match_data.id_r.astype('str')
duplicate_candidates.id_l = duplicate_candidates.id_l.astype('str')
duplicate_candidates.id_r = duplicate_candidates.id_r.astype('str')

#merging matched_records df with original record data for ease of review
l_conc = pd.merge(duplicate_candidates, left_match_data, on='id_l')
full_conc = pd.merge(l_conc, right_match_data, on='id_r')

print("original data concatenated with matches --- %s seconds ---" % (time.time() - start_time))
print ""

start_time = time.time()
print "SCORING ORG NAME SIMULARITY..." #<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<

#scoring match candidates based on edit distance of org names
def jaro_simularity(left_record, right_record):
    if isinstance(left_record, numbers.Integral) is False and isinstance(right_record, numbers.Integral) is False:
        return jaro_winkler(unicode(left_record, 'utf-8') or '', unicode(right_record, 'utf-8') or '')
def fuzz_partial(left_record, right_record):
    if isinstance(left_record, numbers.Integral) is False and isinstance(right_record, numbers.Integral) is False:
        return fuzz.partial_ratio(unicode(left_record, 'utf-8') or '', unicode(right_record, 'utf-8') or '') / float(100)
def fuzz_sort(left_record, right_record):
    if isinstance(left_record, numbers.Integral) is False and isinstance(right_record, numbers.Integral) is False:
        return fuzz.token_sort_ratio(unicode(left_record, 'utf-8') or '', unicode(right_record, 'utf-8') or '') / float(100)
def fuzz_set(left_record, right_record):
    if isinstance(left_record, numbers.Integral) is False and isinstance(right_record, numbers.Integral) is False:
        return fuzz.token_set_ratio(unicode(left_record, 'utf-8') or '', unicode(right_record, 'utf-8') or '') / float(100)

full_conc['l_org_name'] = full_conc['l_org_name'].astype('str')
full_conc['r_org_name'] = full_conc['r_org_name'].astype('str')

full_conc['jaro_score'] = full_conc.apply(lambda x: jaro_simularity(x.l_org_name, x.r_org_name), axis=1)
full_conc['fuzz_partial_score'] = full_conc.apply(lambda x: fuzz_partial(x.l_org_name, x.r_org_name), axis=1)
full_conc['fuzz_sort_score'] = full_conc.apply(lambda x: fuzz_sort(x.l_org_name, x.r_org_name), axis=1)
full_conc['fuzz_set_score'] = full_conc.apply(lambda x: fuzz_set(x.l_org_name, x.r_org_name), axis=1)

print("name simularity scored --- %s seconds ---" % (time.time() - start_time))
print ""

start_time = time.time()
print "CHECKING FOR STATE CODE MATCHES..." #<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<

def sanitize_state(state):
    if isinstance(state,basestring) is True:
        return ''.join(c for c in (state or '') if c in 'abcdefghijklmnopqrstuvwxyz')
    else:
        return ''
    
def state_match(state_a, state_b):
    sanitized_state_a = str(sanitize_state(state_a))
    sanitized_state_b = str(sanitize_state(state_b))

    # if the value is too short, means it's fubar
    if len(sanitized_state_a) < 2 or len(sanitized_state_b) < 2:
        return 0
    if state_a == state_b:
        return 1
    else:
        return 0    

full_conc['state_match'] = full_conc.apply(lambda x: state_match(x.l_state, x.r_state), axis=1)

print("state codes checked --- %s seconds ---" % (time.time() - start_time))
print ""

start_time = time.time()
print "CHECKING FOR POSTAL CODE MATCHES..." #<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<

#scoring match candidates based on matching postal code

def sanitize_postal(postal):
    if isinstance(postal, basestring) is True:
        return ''.join(c for c in (postal or '') if c in '1234567890')
    if isinstance(postal, float) is False:
        return postal

def postal_simularity(postal_a, postal_b):
    sanitized_postal_a = str(sanitize_postal(postal_a))
    sanitized_postal_b = str(sanitize_postal(postal_b))

    # if the number is too short, means it's fubar
    if len(sanitized_postal_a) < 5 or len(sanitized_postal_b) < 5:
        return 0
    if float(max(len(sub) for sub in find_common_subsequences(sanitized_postal_a, sanitized_postal_b))) / 5 >= 1:
        return 1
    else:
        return 0
    
full_conc['zip_match'] = full_conc.apply(lambda x: postal_simularity(x.l_postal_code, x.r_postal_code), axis=1)
    
print("postal codes checked --- %s seconds ---" % (time.time() - start_time))
print ""

#start_time = time.time()
#print "CHECKING FOR PHONE MATCHES..." #<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<

#scoring match candidates based on matching postal code

#def sanitize_phone(phone):
#    if isinstance(phone, basestring) is True:
#        return ''.join(c for c in (phone or '') if c in '1234567890')
#    if isinstance(phone, float) is False:
#        return phone

#def postal_simularity(phone_a, phone_b):
#    sanitized_phone_a = str(sanitize_phone(phone_a))
#    sanitized_phone_b = str(sanitize_phone(phone_b))

    # if the number is too short, means it's fubar
#    if len(sanitized_phone_a) < 10 or len(sanitized_phone_b) < 10:
#        return 0
#    if float(max(len(sub) for sub in find_common_subsequences(sanitized_phone_a, sanitized_phone_b))) / 10 >= 1:
#        return 1
#    else:
#        return 0
    
#full_conc['phone_match'] = full_conc.apply(lambda x: phone_simularity(x.l_phone, x.r_phone), axis=1)
    
#print("phones checked --- %s seconds ---" % (time.time() - start_time))
#print ""

#test this.  may need to make more efficient but I think it should work
start_time = time.time()
print "DISTILLING STRONG, UNIQUE ORG DUPLICATES..." #<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<

#calculate composite match score based on component scores and weights
full_conc['composite_match_score'] = full_conc.jaro_score * name_weight \
+ full_conc.fuzz_partial_score * name_weight \
+ full_conc.fuzz_sort_score * name_weight \
+ full_conc.fuzz_set_score * name_weight \
+ full_conc.zip_match * zip_weight \
+ full_conc.state_match * state_weight \
#+ full_conc.phone_match * phone_weight

org_matches = full_conc[full_conc.composite_match_score >= composite_score_min]

match_tuples = list(zip(org_matches['id_l'], org_matches['id_r']))

unique_match_tuples = []
seen = set()
for tup in match_tuples:
    s = tuple(sorted(tup))
    if s not in seen:
        seen.add(s)
        unique_match_tuples.append(tup)

unique_flag = []
for tup in match_tuples:
    if tup in unique_match_tuples:
        unique_flag.append(1)
    else:
        unique_flag.append(0)
        
org_matches['unique_flag'] = unique_flag

unique_matches = org_matches[org_matches['unique_flag'] == 1]

print("final duplicates isolated --- %s seconds ---" % (time.time() - start_time))
print ""

#full_conc[full_conc.composite_match_score < 3].sort_values(by='composite_match_score', ascending=False)
unique_matches.sort_values(by='composite_match_score', ascending=False)
# Out:
# LOADING DATAFRAMES INTO MEMORY...
# C:\Users\dbell\AppData\Local\Continuum\anaconda2\lib\site-packages\IPython\core\interactiveshell.py:2718: DtypeWarning: Columns (0,1) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# dataframes loaded --- 0.783999919891 seconds ---
#
# PRE-PROCESSING: NORMALIZE STATES...
# states normalized --- 1.10000014305 seconds ---
#
# CREATING DICTIONARY OF ALL UNIQUE TOKENS W INCLUDE FLAG...
# token dictionary created --- 12.7979998589 seconds ---
#
# TOKENIZING LEFT DATAFRAME...
# left dataframe tokenized --- 11.6840000153 seconds ---
#
# TOKENIZING RIGHT DATAFRAME...
# right dataframe tokenized --- 0.0130000114441 seconds ---
#
# JOINING LEFT & RIGHT TOKEN KEYS...
# MemoryErrorTraceback (most recent call last)
# <ipython-input-2-f553f6e5dd12> in <module>()
#     241
#     242 #join left and right token keys
# --> 243 joined = left_keyed.join(right_keyed, how='inner',lsuffix='_l',rsuffix='_r')
#     244
#     245 print("left & right token keys joined --- %s seconds ---" % (time.time() - start_time))
#
# C:\Users\dbell\AppData\Local\Continuum\anaconda2\lib\site-packages\pandas\core\frame.pyc in join(self, other, on, how, lsuffix, rsuffix, sort)
#    6334         # For SparseDataFrame's benefit
#    6335         return self._join_compat(other, on=on, how=how, lsuffix=lsuffix,
# -> 6336                                  rsuffix=rsuffix, sort=sort)
#    6337
#    6338     def _join_compat(self, other, on=None, how='left', lsuffix='', rsuffix='',
#
# C:\Users\dbell\AppData\Local\Continuum\anaconda2\lib\site-packages\pandas\core\frame.pyc in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    6349             return merge(self, other, left_on=on, how=how,
#    6350                          left_index=on is None, right_index=True,
# -> 6351                          suffixes=(lsuffix, rsuffix), sort=sort)
#    6352         else:
#    6353             if on is not None:
#
# C:\Users\dbell\AppData\Local\Continuum\anaconda2\lib\site-packages\pandas\core\reshape\merge.pyc in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      60                          copy=copy, indicator=indicator,
#      61                          validate=validate)
# ---> 62     return op.get_result()
#      63
#      64
#
# C:\Users\dbell\AppData\Local\Continuum\anaconda2\lib\site-packages\pandas\core\reshape\merge.pyc in get_result(self)
#     566                 self.left, self.right)
#     567
# --> 568         join_index, left_indexer, right_indexer = self._get_join_info()
#     569
#     570         ldata, rdata = self.left._data, self.right._data
#
# C:\Users\dbell\AppData\Local\Continuum\anaconda2\lib\site-packages\pandas\core\reshape\merge.pyc in _get_join_info(self)
#     763             join_index, left_indexer, right_indexer = \
#     764                 left_ax.join(right_ax, how=self.how, return_indexers=True,
# --> 765                              sort=self.sort)
#     766         elif self.right_index and self.how == 'left':
#     767             join_index, left_indexer, right_indexer = \
#
# C:\Users\dbell\AppData\Local\Continuum\anaconda2\lib\site-packages\pandas\core\indexes\base.pyc in join(self, other, how, level, return_indexers, sort)
#    3776         if not self.is_unique and not other.is_unique:
#    3777             return self._join_non_unique(other, how=how,
# -> 3778                                          return_indexers=return_indexers)
#    3779         elif not self.is_unique or not other.is_unique:
#    3780             if self.is_monotonic and other.is_monotonic:
#
# C:\Users\dbell\AppData\Local\Continuum\anaconda2\lib\site-packages\pandas\core\indexes\base.pyc in _join_non_unique(self, other, how, return_indexers)
#    3865                                                  [other._ndarray_values],
#    3866                                                  how=how,
# -> 3867                                                  sort=True)
#    3868
#    3869         left_idx = _ensure_platform_int(left_idx)
#
# C:\Users\dbell\AppData\Local\Continuum\anaconda2\lib\site-packages\pandas\core\reshape\merge.pyc in _get_join_indexers(left_keys, right_keys, sort, how, **kwargs)
#    1146     join_func = _join_functions[how]
#    1147
# -> 1148     return join_func(lkey, rkey, count, **kwargs)
#    1149
#    1150
#
# pandas/_libs/join.pyx in pandas._libs.join.inner_join()
#
# pandas/_libs/join.pyx in pandas._libs.join._get_result_indexer()
#
# C:\Users\dbell\AppData\Local\Continuum\anaconda2\lib\site-packages\pandas\core\algorithms.pyc in take_nd(arr, indexer, axis, out, fill_value, mask_info, allow_fill)
#    1651             # (s.t. df.values is c-contiguous and df._data.blocks[0] is its
#    1652             # f-contiguous transpose)
# -> 1653             out = np.empty(out_shape, dtype=dtype, order='F')
#    1654         else:
#    1655             out = np.empty(out_shape, dtype=dtype)
#
# MemoryError:

# %%
left_keyed.shape
# Out:
# (1637244, 1)

# %%
full_conc.shape
# Out:
# (345622, 20)

# %%
left_keyed = left_keyed.reset_index(inplace=True)
left_keyed

# %%
right_keyed
# Out:
#                         token      id
# token_id
# 30381                     501       1
# 81204                 commons       1
# 130163                   leaf       2
# 150776                 womans       3
# 161424                  place       3
# 86367                    aarp       4
# 86367                    aarp       5
# 116892               hospital       6
# 152281                  abbot       6
# 154354           northwestern       6
# 275                    abbott       7
# 126458                  house       7
# 76427               christian       8
# 49334                 abilene       8
# 12153                 ability       9
# 12153                 ability      10
# 146827                 counts      10
# 11835                      ac      11
# 93680                portland      11
# 40231                 academy      12
# 17042                    arts      13
# 40231                 academy      13
# 8887                 sciences      13
# 40231                 academy      14
# 52446                    prep      14
# 84113                   tampa      14
# 106726                   acca      15
# 49794                  access      16
# 49794                  access      17
# 126232                network      17
# ...                       ...     ...
# 31239                     edu  237763
# 29051                wvstateu  237763
# 66500                     tri  237771
# 121988          theclaycenter  237772
# 114428                   pets  237782
# 154421                   rchs  237782
# 31239                     edu  237793
# 111598                 alumni  237793
# 73087                    rccr  237797
# 82901                   youth  237804
# 126165                  wvpca  237811
# 104568                 patton  237812
# 167117                  craik  237812
# 25285               hospitals  237817
# 72583                   about  237817
# 87630                     wvu  237817
# 77255          carnegiehallwv  237819
# 15375         youthleadership  237828
# 162464                    yla  237828
# 157093                  shack  237829
# 62300       educationalliance  237831
# 34770                    nysf  237832
# 110124              changeinc  237833
# 32910                    sals  237844
# 48712                    info  237844
# 85849                    ovmc  237847
# 59122     youthservicessystem  237869
# 58888                     net  237879
# 4202                  daymark  237887
# 157212           wvhumanities  237891
#
# [1637244 rows x 2 columns]

# %%
joined[joined.id_l <> joined.id_r]
# Out:
#              token_l    id_l       token_r    id_r
# 0                501       1  turnanewleaf       2
# 0               12th       1  turnanewleaf       2
# 0            seattle       1  turnanewleaf       2
# 0                 wa       1  turnanewleaf       2
# 0              98144       1  turnanewleaf       2
# 0       turnanewleaf       2           501       1
# 0       turnanewleaf       2          12th       1
# 0       turnanewleaf       2       seattle       1
# 0       turnanewleaf       2            wa       1
# 0       turnanewleaf       2         98144       1
# 1            commons       1         tulsa       2
# 1            commons       1            ok       2
# 1            commons       1         10001       4
# 1            commons       1  awomansplace       3
# 1               1200       1         tulsa       2
# 1               1200       1            ok       2
# 1               1200       1         10001       4
# 1               1200       1  awomansplace       3
# 1              tulsa       2       commons       1
# 1              tulsa       2          1200       1
# 1              tulsa       2         10001       4
# 1              tulsa       2  awomansplace       3
# 1                 ok       2       commons       1
# 1                 ok       2          1200       1
# 1                 ok       2         10001       4
# 1                 ok       2  awomansplace       3
# 1              10001       4       commons       1
# 1              10001       4          1200       1
# 1              10001       4         tulsa       2
# 1              10001       4            ok       2
# ...              ...     ...           ...     ...
# 447090     adventure  187131        tavern  237883
# 447090        tavern  237883     adventure  187131
# 447091      veterans  187131            99  237883
# 447091            99  237883      veterans  187131
# 447092      national  187132      hospital  237884
# 447092      hospital  237884      national  187132
# 447093    prevention  187132           117  237884
# 447093           117  237884    prevention  187132
# 447094      violence  187132       jackson  237886
# 447094       jackson  237886      violence  187132
# 447095     montclair  187133           120  237886
# 447095           120  237886     montclair  187133
# 447096  contemporary  187134           510  237888
# 447096           510  237888  contemporary  187134
# 447097       fundinc  187134          mill  237889
# 447097          mill  237889       fundinc  187134
# 447098         artis  187134           208  237889
# 447098           208  237889         artis  187134
# 447099       israeli  187134           old  237889
# 447099           old  237889       israeli  187134
# 447100           art  187134           400  237890
# 447100           400  237890           art  187134
# 447101      sycamore  187135     jefferson  237890
# 447101     jefferson  237890      sycamore  187135
# 447102          lane  187135     boulevard  237891
# 447102     boulevard  237891          lane  187135
# 447103        riding  187135       kanawha  237891
# 447103       kanawha  237891        riding  187135
# 447104   therapeutic  187135          1310  237891
# 447104          1310  237891   therapeutic  187135
#
# [4440366 rows x 4 columns]

# %%
full_conc[full_conc.id_l == '1']
# Out:
#     id_l count id_r id_l   l_org_name   l_city l_state l_postal_code  \
# 0           10    2    1  501 COMMONS  SEATTLE      wa         98144
# 6            4    3    1  501 COMMONS  SEATTLE      wa         98144
# 13           3    4    1  501 COMMONS  SEATTLE      wa         98144
#
#                         l_web      r_org_name      r_city r_state  \
# 0   HTTP://WWW.501COMMONS.ORG      A New Leaf       Tulsa      ok
# 6   HTTP://WWW.501COMMONS.ORG  A WOMANS PLACE  DOYLESTOWN      pa
# 13  HTTP://WWW.501COMMONS.ORG            AARP    NEW YORK      ny
#
#    r_postal_code                 r_web  jaro_score  fuzz_partial_score  \
# 0          74153  WWW.TURNANEWLEAF.ORG    0.396970                0.21
# 6          18901  WWW.AWOMANSPLACE.ORG    0.603896                0.45
# 13         10001          www.aarp.org    0.000000                0.00
#
#     fuzz_sort_score  fuzz_set_score  state_match  zip_match  \
# 0              0.19            0.19            0          0
# 6              0.48            0.48            0          0
# 13             0.00            0.00            0          0
#
#     composite_match_score
# 0                0.740227
# 6                1.510422
# 13               0.000000

# %%
left_keyed[left_keyed.id == '1']
# Out:
#      token id
# 0      501  1
# 1  commons  1
# 0     12th  1
# 1     1200  1
# 2     1101  1
# 0  seattle  1
# 0       wa  1
# 0    98144  1

# %%
right_keyed[right_keyed.id == '2']
# Out:
#           token id
# 2          leaf  2
# 3          9810  2
# 4          42nd  2
# 1         tulsa  2
# 1            ok  2
# 0  turnanewleaf  2

# %%
full_conc[full_conc.id_l == '5']
# Out:
#         id_l count id_r id_l        l_org_name      l_city l_state  \
# 3                3    2    5  AARP FOUNDATIION  WASHINGTON      dc
# 9                4    3    5  AARP FOUNDATIION  WASHINGTON      dc
# 17               3    4    5  AARP FOUNDATIION  WASHINGTON      dc
# 95               6    6    5  AARP FOUNDATIION  WASHINGTON      dc
# 108              2    8    5  AARP FOUNDATIION  WASHINGTON      dc
# 33963            4    7    5  AARP FOUNDATIION  WASHINGTON      dc
# 59172            2   13    5  AARP FOUNDATIION  WASHINGTON      dc
# 132668           2   11    5  AARP FOUNDATIION  WASHINGTON      dc
#
#        l_postal_code                    l_web                    r_org_name  \
# 3              20049  www.aarp.org/foundation                    A New Leaf
# 9              20049  www.aarp.org/foundation                A WOMANS PLACE
# 17             20049  www.aarp.org/foundation                          AARP
# 95             20049  www.aarp.org/foundation   ABBOT NORTHWESTERN HOSPITAL
# 108            20049  www.aarp.org/foundation  ABILENE CHRISTIAN UNIVERSITY
# 33963          20049  www.aarp.org/foundation                  Abbott House
# 59172          20049  www.aarp.org/foundation  ACADEMY OF ARTS AND SCIENCES
# 132668         20049  www.aarp.org/foundation                   AC PORTLAND
#
#               r_city r_state r_postal_code                              r_web  \
# 3              Tulsa      ok         74153               WWW.TURNANEWLEAF.ORG
# 9         DOYLESTOWN      pa         18901               WWW.AWOMANSPLACE.ORG
# 17          NEW YORK      ny         10001                       www.aarp.org
# 95       MINNEAPOLIS      mn         55407  SEE STATEMENT FOR WEBSITE ADDRESS
# 108          ABILENE      tx         79699                        www.acu.edu
# 33963      Irvington      ny         10533                WWW.ABBOTTHOUSE.ORG
# 59172   PHILADELPHIA      pa         19103                     WWW.AMACAD.ORG
# 132668      PORTLAND      or         97217                     ACPORTLAND.ORG
#
#         jaro_score  fuzz_partial_score  fuzz_sort_score  fuzz_set_score  \
# 3         0.495833                0.30             0.31            0.31
# 9         0.550595                0.36             0.40            0.40
# 17        0.850000                1.00             0.40            1.00
# 95        0.520833                0.25             0.28            0.28
# 108       0.527381                0.38             0.32            0.32
# 33963     0.430556                0.17             0.29            0.29
# 59172     0.642857                0.44             0.41            0.41
# 132668    0.645412                0.45             0.37            0.37
#
#         state_match  zip_match  composite_match_score
# 3                 0          0               1.061875
# 9                 0          0               1.282946
# 17                0          0               2.437500
# 95                0          0               0.998125
# 108               0          0               1.160536
# 33963             0          0               0.885417
# 59172             0          0               1.427143
# 132668            0          0               1.376559

# %%
valid_tokens = []
for token, value in tokens_dct.items():
    if value == 1:
        valid_tokens.append(token)
        
len(valid_tokens)
# Out:
# 74579

# %%
[len(x) for x in tokens_dct.values()]
sum([len(x) for x in tokens_dct.values()])

# %%
tokens_dct
length_key = len(tokens_dct[1])
# Out:
# KeyErrorTraceback (most recent call last)
# <ipython-input-95-6ae5c0e0f5b3> in <module>()
#       1 tokens_dct
# ----> 2 length_key = len(tokens_dct[1])
#
# KeyError: 1

# %%
vocabulary = np.array([w for w, b in tokens_dct.items() if b])
len(vocabulary)
# Out:
# 74579

# %%
left_keyed[left_keyed.id == '1']
# Out:
#      token id
# 0      501  1
# 1  commons  1
# 0     12th  1
# 1     1200  1
# 2     1101  1
# 0  seattle  1
# 0       wa  1
# 0    98144  1

# %%
duplicate_candidates.shape
# Out:
# (3938, 3)

# %%
full_conc.head()
# Out:
#    id_l count id_r id_l                    l_org_name    l_city l_state  \
# 0           3   10    1                   501 COMMONS   SEATTLE      wa
# 1           2   10    8  ABILENE CHRISTIAN UNIVERSITY   ABILENE      tx
# 2           4    2    1                   501 COMMONS   SEATTLE      wa
# 3           2    2    4                          AARP  NEW YORK      ny
# 4           2   22    1                   501 COMMONS   SEATTLE      wa
#
#   l_postal_code                      l_web          r_org_name     r_city  \
# 0         98144  HTTP://WWW.501COMMONS.ORG  ABILITY COUNTS INC     CORONA
# 1         79699                www.acu.edu  ABILITY COUNTS INC     CORONA
# 2         98144  HTTP://WWW.501COMMONS.ORG          A New Leaf      Tulsa
# 3         10001               www.aarp.org          A New Leaf      Tulsa
# 4         98144  HTTP://WWW.501COMMONS.ORG                 ACT  SAN DIEGO
#
#   r_state r_postal_code                 r_web  jaro_score  fuzz_partial_score  \
# 0      ca         92879                  NULL    0.577441                0.45
# 1      ca         92879                  NULL    0.640212                0.44
# 2      ok         74153  WWW.TURNANEWLEAF.ORG    0.396970                0.21
# 3      ok         74153  WWW.TURNANEWLEAF.ORG    0.450000                0.25
# 4      ca         92121           WWW.ACT.ORG    0.474747                0.33
#
#    fuzz_sort_score  fuzz_set_score  state_match  zip_match  \
# 0             0.34            0.34            0          0
# 1             0.30            0.30            0          0
# 2             0.19            0.19            0          0
# 3             0.29            0.29            0          0
# 4             0.14            0.14            0          0
#
#    composite_match_score
# 0               1.280581
# 1               1.260159
# 2               0.740227
# 3               0.960000
# 4               0.813561

# %%
full_conc[full_conc.id_l =='1']
# Out:
#     id_l count id_r id_l   l_org_name   l_city l_state l_postal_code  \
# 0            3   10    1  501 COMMONS  SEATTLE      wa         98144
# 2            4    2    1  501 COMMONS  SEATTLE      wa         98144
# 4            2   22    1  501 COMMONS  SEATTLE      wa         98144
# 11           2    3    1  501 COMMONS  SEATTLE      wa         98144
# 13           4    4    1  501 COMMONS  SEATTLE      wa         98144
#
#                         l_web          r_org_name      r_city r_state  \
# 0   HTTP://WWW.501COMMONS.ORG  ABILITY COUNTS INC      CORONA      ca
# 2   HTTP://WWW.501COMMONS.ORG          A New Leaf       Tulsa      ok
# 4   HTTP://WWW.501COMMONS.ORG                 ACT   SAN DIEGO      ca
# 11  HTTP://WWW.501COMMONS.ORG      A WOMANS PLACE  DOYLESTOWN      pa
# 13  HTTP://WWW.501COMMONS.ORG                AARP    NEW YORK      ny
#
#    r_postal_code                 r_web  jaro_score  fuzz_partial_score  \
# 0          92879                  NULL    0.577441                0.45
# 2          74153  WWW.TURNANEWLEAF.ORG    0.396970                0.21
# 4          92121           WWW.ACT.ORG    0.474747                0.33
# 11         18901  WWW.AWOMANSPLACE.ORG    0.603896                0.45
# 13         10001          www.aarp.org    0.000000                0.00
#
#     fuzz_sort_score  fuzz_set_score  state_match  zip_match  \
# 0              0.34            0.34            0          0
# 2              0.19            0.19            0          0
# 4              0.14            0.14            0          0
# 11             0.48            0.48            0          0
# 13             0.00            0.00            0          0
#
#     composite_match_score
# 0                1.280581
# 2                0.740227
# 4                0.813561
# 11               1.510422
# 13               0.000000

# %%
#join left and right token keys
joined = left_keyed.join(right_keyed.set_index('token'), on='token', how='inner',lsuffix='_l',rsuffix='_r')
# Out:
# MemoryErrorTraceback (most recent call last)
# <ipython-input-6-91ab016ff53f> in <module>()
#       1 #join left and right token keys
# ----> 2 joined = left_keyed.join(right_keyed.set_index('token'), on='token', how='inner',lsuffix='_l',rsuffix='_r')
#
# C:\Users\Duncan\Anaconda2\lib\site-packages\pandas\core\frame.pyc in join(self, other, on, how, lsuffix, rsuffix, sort)
#    4667         # For SparseDataFrame's benefit
#    4668         return self._join_compat(other, on=on, how=how, lsuffix=lsuffix,
# -> 4669                                  rsuffix=rsuffix, sort=sort)
#    4670
#    4671     def _join_compat(self, other, on=None, how='left', lsuffix='', rsuffix='',
#
# C:\Users\Duncan\Anaconda2\lib\site-packages\pandas\core\frame.pyc in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    4682             return merge(self, other, left_on=on, how=how,
#    4683                          left_index=on is None, right_index=True,
# -> 4684                          suffixes=(lsuffix, rsuffix), sort=sort)
#    4685         else:
#    4686             if on is not None:
#
# C:\Users\Duncan\Anaconda2\lib\site-packages\pandas\core\reshape\merge.pyc in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator)
#      52                          right_index=right_index, sort=sort, suffixes=suffixes,
#      53                          copy=copy, indicator=indicator)
# ---> 54     return op.get_result()
#      55
#      56
#
# C:\Users\Duncan\Anaconda2\lib\site-packages\pandas\core\reshape\merge.pyc in get_result(self)
#     567                 self.left, self.right)
#     568
# --> 569         join_index, left_indexer, right_indexer = self._get_join_info()
#     570
#     571         ldata, rdata = self.left._data, self.right._data
#
# C:\Users\Duncan\Anaconda2\lib\site-packages\pandas\core\reshape\merge.pyc in _get_join_info(self)
#     732         else:
#     733             (left_indexer,
# --> 734              right_indexer) = self._get_join_indexers()
#     735
#     736             if self.right_index:
#
# C:\Users\Duncan\Anaconda2\lib\site-packages\pandas\core\reshape\merge.pyc in _get_join_indexers(self)
#     711                                   self.right_join_keys,
#     712                                   sort=self.sort,
# --> 713                                   how=self.how)
#     714
#     715     def _get_join_info(self):
#
# C:\Users\Duncan\Anaconda2\lib\site-packages\pandas\core\reshape\merge.pyc in _get_join_indexers(left_keys, right_keys, sort, how, **kwargs)
#     996     join_func = _join_functions[how]
#     997
# --> 998     return join_func(lkey, rkey, count, **kwargs)
#     999
#    1000
#
# pandas\_libs\join.pyx in pandas._libs.join.inner_join()
#
# MemoryError:

# %%
left_match_data.dtypes
# Out:
# id_l              int64
# l_org_name       object
# l_city           object
# l_state          object
# l_postal_code    object
# l_web            object
# dtype: object

# %%
l_conc = pd.merge(duplicate_candidates, left_match_data, on='id_l')

# %%
left_match_data[left_match_data.id_l == 101201]
# Out:
#        id_l                  l_org_name l_city l_state l_postal_code l_web
# 464  101201  YUMA CONSERVATION DISTRICT   YUMA      co         80759     0

# %%
dups.head()
# Out:
#      id_l    id_r  id_l count
# 0  101201  130422           2
# 1  101201   26720           2
# 2  101201   73321           2
# 3  101201   85468           2
# 4  103563  221817           2

# %%
left_match_data.id_l = left_match_data.id_l.astype('str')
dups.id_l = duplicate_candidates.id_l.astype('str')

# %%
left_match_data.id_l = left_match_data.id_l.astype('str')
dups.id_l = duplicate_candidates.id_l.astype('str')

l_conc = pd.merge(dups,left_match_data,on='id_l')
l_conc.shape
# Out:
# (12348, 8)

# %%
dups
# Out:
#          id_l    id_r  id_l count
# 0      101201  130422           2
# 1      101201   26720           2
# 2      101201   73321           2
# 3      101201   85468           2
# 4      103563  221817           2
# 5      103563   59174           2
# 6       10518   14330           2
# 7       10518   67891           2
# 8       10518   67892           2
# 9       10518   77063           2
# 10      10518   83351           2
# 11     105326   37876           2
# 12     105436   40753           2
# 13      10600   10601           2
# 14      10600  203426           2
# 15      10601   10600           2
# 16      10601  203426           2
# 17     108282  203426           2
# 18     108399  175447           2
# 19     108399  181310           2
# 20     108419  212884           2
# 21     108515  203426           2
# 22     109728   85468           2
# 23     110291  146551           2
# 24     110291   72994           2
# 25     110291   75839           2
# 26     110291   79412           2
# 27     111725  175447           2
# 28     111725  181310           2
# 29     113039   83733           2
# ...       ...     ...         ...
# 12318   91836  203426           2
# 12319   91880    3300           2
# 12320   92432  203426           2
# 12321   92656   45032           2
# 12322   92656   94892           2
# 12323   92986   83733           2
# 12324   93159  203426           2
# 12325   93443  115937           2
# 12326   93443   83733           2
# 12327   94051   41564           2
# 12328   94759   77417           2
# 12329   94759   83733           2
# 12330   94892   45032           2
# 12331   94892   92656           2
# 12332   95066  178363           2
# 12333   95250  175447           2
# 12334   95250  181310           2
# 12335   96018   56701           2
# 12336   96183   82905           2
# 12337    9659   13290           2
# 12338   97126   47356           2
# 12339   97139  178363           2
# 12340   97588  203426           2
# 12341    9849   37876           2
# 12342   98637  203426           2
# 12343   98637   25056           2
# 12344   99188  118782           2
# 12345   99188  147241           2
# 12346   99188  203426           2
# 12347   99188   46487           2
#
# [12348 rows x 3 columns]

# %%
dups = duplicate_candidates[['id_l count']]
dups.reset_index(inplace=True)
dups
# Out:
#          id_l    id_r  id_l count
# 0      101201  130422           2
# 1      101201   26720           2
# 2      101201   73321           2
# 3      101201   85468           2
# 4      103563  221817           2
# 5      103563   59174           2
# 6       10518   14330           2
# 7       10518   67891           2
# 8       10518   67892           2
# 9       10518   77063           2
# 10      10518   83351           2
# 11     105326   37876           2
# 12     105436   40753           2
# 13      10600   10601           2
# 14      10600  203426           2
# 15      10601   10600           2
# 16      10601  203426           2
# 17     108282  203426           2
# 18     108399  175447           2
# 19     108399  181310           2
# 20     108419  212884           2
# 21     108515  203426           2
# 22     109728   85468           2
# 23     110291  146551           2
# 24     110291   72994           2
# 25     110291   75839           2
# 26     110291   79412           2
# 27     111725  175447           2
# 28     111725  181310           2
# 29     113039   83733           2
# ...       ...     ...         ...
# 12318   91836  203426           2
# 12319   91880    3300           2
# 12320   92432  203426           2
# 12321   92656   45032           2
# 12322   92656   94892           2
# 12323   92986   83733           2
# 12324   93159  203426           2
# 12325   93443  115937           2
# 12326   93443   83733           2
# 12327   94051   41564           2
# 12328   94759   77417           2
# 12329   94759   83733           2
# 12330   94892   45032           2
# 12331   94892   92656           2
# 12332   95066  178363           2
# 12333   95250  175447           2
# 12334   95250  181310           2
# 12335   96018   56701           2
# 12336   96183   82905           2
# 12337    9659   13290           2
# 12338   97126   47356           2
# 12339   97139  178363           2
# 12340   97588  203426           2
# 12341    9849   37876           2
# 12342   98637  203426           2
# 12343   98637   25056           2
# 12344   99188  118782           2
# 12345   99188  147241           2
# 12346   99188  203426           2
# 12347   99188   46487           2
#
# [12348 rows x 3 columns]

# %%
left_match_data.to_csv('left_match_data test.csv')

# %%
unique_matches.id_l.value_counts()
# Out:
# 556       3
# 94532     2
# 99002     2
# 1370      2
# 46939     2
# 94860     2
# 91681     1
# 94523     1
# 16184     1
# 94517     1
# 90440     1
# 103138    1
# 19502     1
# 100013    1
# 82218     1
# 81722     1
# 90271     1
# 99230     1
# 46876     1
# 94269     1
# 99354     1
# 89208     1
# 76437     1
# 46606     1
# 88011     1
# 95116     1
# 99338     1
# 66735     1
# 89992     1
# 2055      1
#          ..
# 94535     1
# 66627     1
# 94965     1
# 83192     1
# 94967     1
# 93557     1
# 18931     1
# 41457     1
# 28272     1
# 239       1
# 91500     1
# 91625     1
# 2022      1
# 82892     1
# 43459     1
# 80482     1
# 94870     1
# 2016      1
# 96990     1
# 27864     1
# 87381     1
# 85198     1
# 1741      1
# 100044    1
# 91211     1
# 48970     1
# 94536     1
# 37319     1
# 6086      1
# 103046    1
# Name: id_l, Length: 61, dtype: int64

# %%
unique_matches[unique_matches.id_l == 556]
# Out:
#        id_l count    id_r  id_l             l_org_name       l_city l_state  \
# 34225           8   80445   556  University of Florida  Gainesville      FL
# 34278           3   94528   556  University of Florida  Gainesville      FL
# 34294           3  101781   556  University of Florida  Gainesville      FL
#
#       l_postal_code       l_web  \
# 34225         32611  www.uf.edu
# 34278         32611  www.uf.edu
# 34294         32611  www.uf.edu
#
#                                               r_org_name       r_city r_state  \
# 34225  University of Florida Student Government Assoc...  Gainesville      FL
# 34278                 University of Florida TREEO Center  Gainesville      FL
# 34294        The University of Florida Board of Trustees  Gainesville      FL
#
#       r_postal_code              r_web  jaro_score  fuzz_partial_score  \
# 34225         32611               NULL    0.880769                 1.0
# 34278         32611  www.treeo.ufl.edu    0.923529                 1.0
# 34294         32611               NULL    0.718346                 1.0
#
#        fuzz_sort_score  fuzz_set_score  zip_match  composite_match_score  \
# 34225             0.58             1.0          1               3.595577
# 34278             0.76             1.0          1               3.762647
# 34294             0.66             1.0          1               3.533760
#
#        unique_flag
# 34225            1
# 34278            1
# 34294            1

# %%
unique_matches.to_csv('university_dups.csv')

# %%
jaro_simularity('emma is happy','saleh is emma')
# Out:
# 0.6185897435897436

# %%
fuzz_partial('emma is happy','saleh is emma')
# Out:
# 0.48

# %%
fuzz_set('emma is happy','saleh is emma')
# Out:
# 0.7

# %%
fuzz_sort('emma is happy','saleh is emma')
# Out:
# 0.54

# %%
unique_matches.to_csv('SF org duplicate pairs.csv')

# %%
matched_records_test = matched_records.reset_index()

match_tuples = []
for tup in matched_records_test[['id_l','id_r']]:
    match_tuples.append(tup)

matched_records_test[['id_l','id_r']]
# Out:
#                        id_l                id_r
# 0        0012K00001XDfP3QAL  0012K00001XDfP3QAL
# 1        0012K00001XDfP3QAL  001A00000134Um0IAE
# 2        0012K00001XDfP4QAL  0012K00001XDfP4QAL
# 3        0012K00001XDfP4QAL  001A00000134hHYIAY
# 4        0012K00001XDfP4QAL  001A00000134hHlIAI
# 5        0012K00001XDfP4QAL  001A00000134hg6IAA
# 6        0012K00001XDfP4QAL  001A00000134hghIAA
# 7        0012K00001XDfP4QAL  001A0000017s1huIAA
# 8        0012K00001XDfP4QAL  001A000001UoXO8IAN
# 9        0012K00001XDfP4QAL  001A000001UoqL4IAJ
# 10       0012K00001XDfP5QAL  0012K00001XDfP5QAL
# 11       0012K00001XDfP6QAL  0012K00001XDfP6QAL
# 12       0012K00001XDfP6QAL  001A00000134TyKIAU
# 13       0012K00001XDfP6QAL  001A00000134Us2IAE
# 14       0012K00001XDfP6QAL  001A00000134Y88IAE
# 15       0012K00001XDfP6QAL  001A00000134hjbIAA
# 16       0012K00001XDfP6QAL  001A00000134lURIAY
# 17       0012K00001XDfP6QAL  001A00000134mMzIAI
# 18       0012K00001XDfP6QAL  001A00000134mNWIAY
# 19       0012K00001XDfP6QAL  001A00000134qExIAI
# 20       0012K00001XDfP6QAL  001A00000134rUOIAY
# 21       0012K00001XDfP6QAL  001A00000134tNWIAY
# 22       0012K00001XDfP6QAL  001A00000134utvIAA
# 23       0012K00001XDfP6QAL  001A00000134uu1IAA
# 24       0012K00001XDfP6QAL  001A00000134uu2IAA
# 25       0012K00001XDfP6QAL  001A00000134uu3IAA
# 26       0012K00001XDfP6QAL  001A000001OPLTXIA5
# 27       0012K00001XDfP6QAL  001A000001P5eehIAB
# 28       0012K00001XDfP6QAL  001A000001PebpDIAR
# 29       0012K00001XDfP7QAL  0012K00001XDfP7QAL
# ...                     ...                 ...
# 1290138  001A000001WXUDTIA5  001A000001OhoWqIAJ
# 1290139  001A000001WXUDTIA5  001A000001P5dtgIAB
# 1290140  001A000001WXUDTIA5  001A000001P6FoGIAV
# 1290141  001A000001WXUDTIA5  001A000001PeWzgIAF
# 1290142  001A000001WXUDTIA5  001A000001PebuoIAB
# 1290143  001A000001WXUDTIA5  001A000001PecHpIAJ
# 1290144  001A000001WXUDTIA5  001A000001PecIwIAJ
# 1290145  001A000001WXUDTIA5  001A000001Pecv3IAB
# 1290146  001A000001WXUDTIA5  001A000001PfDyyIAF
# 1290147  001A000001WXUDTIA5  001A000001SCBrRIAX
# 1290148  001A000001WXUDTIA5  001A000001USVpvIAH
# 1290149  001A000001WXUDTIA5  001A000001USVqSIAX
# 1290150  001A000001WXUDTIA5  001A000001USVqzIAH
# 1290151  001A000001WXUDTIA5  001A000001USVsFIAX
# 1290152  001A000001WXUDTIA5  001A000001WXUDTIA5
# 1290153  001A000001WXUHuIAP  001A000001WXUHuIAP
# 1290154  001A000001WXUIiIAP  001A000001WXUIiIAP
# 1290155  001A000001WXUIjIAP  001A000001WXUIjIAP
# 1290156  001A000001WXUIkIAP  001A000001HHM21IAH
# 1290157  001A000001WXUIkIAP  001A000001PfjpzIAB
# 1290158  001A000001WXUIkIAP  001A000001WXUIkIAP
# 1290159  001A000001WXUIlIAP  001A00000134U6vIAE
# 1290160  001A000001WXUIlIAP  001A000001PebqoIAB
# 1290161  001A000001WXUIlIAP  001A000001WVWWlIAP
# 1290162  001A000001WXUIlIAP  001A000001WVcfsIAD
# 1290163  001A000001WXUIlIAP  001A000001WXUIlIAP
# 1290164  001A000001WXUImIAP  001A000001WXUImIAP
# 1290165  001A000001WXUXcIAP  001A000001WXUXcIAP
# 1290166  001A000001WXUdWIAX  001A000001OhoVIIAZ
# 1290167  001A000001WXUdWIAX  001A000001WXUdWIAX
#
# [1290168 rows x 2 columns]

# %%
duplicate_candidates.head()
# Out:
#                                        id_l count                id_r  \
# id_l               id_r
# 0012K00001XDfP3QAL 001A00000134Um0IAE           3  001A00000134Um0IAE
# 0012K00001XDfP4QAL 001A00000134hHYIAY           2  001A00000134hHYIAY
#                    001A00000134hHlIAI           2  001A00000134hHlIAI
#                    001A00000134hg6IAA           4  001A00000134hg6IAA
#                    001A00000134hghIAA           2  001A00000134hghIAA
#
#                                                      id_l
# id_l               id_r
# 0012K00001XDfP3QAL 001A00000134Um0IAE  0012K00001XDfP3QAL
# 0012K00001XDfP4QAL 001A00000134hHYIAY  0012K00001XDfP4QAL
#                    001A00000134hHlIAI  0012K00001XDfP4QAL
#                    001A00000134hg6IAA  0012K00001XDfP4QAL
#                    001A00000134hghIAA  0012K00001XDfP4QAL

# %%
duplicate_candidates.shape
# Out:
# (1201994, 3)

# %%
#test this.  may need to make more efficient but I think it should work
start_time = time.time()
print "dealing with tuples..."

match_tuples = list(zip(org_matches['id_l'], org_matches['id_r']))

unique_match_tuples = []
seen = set()
for tup in match_tuples:
    s = tuple(sorted(tup))
    if s not in seen:
        seen.add(s)
        unique_match_tuples.append(tup)

unique_flag = []
for tup in match_tuples:
    if tup in unique_match_tuples:
        unique_flag.append(1)
    else:
        unique_flag.append(0)
        
org_matches['unique_flag'] = unique_flag

unique_matches = org_matches[org_matches['unique_flag'] == 1]

print("tuples loaded --- %s seconds ---" % (time.time() - start_time))
print ""
unique_matches.shape
# Out:
# dealing with tuples...
# tuples loaded --- 18.8469998837 seconds ---
# C:\Users\dbell\AppData\Local\Continuum\anaconda2\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# (13288, 19)

# %%
org_matches['unique_flag'] = unique_flag
org_matches.unique_flag.value_counts()
# Out:
# C:\Users\dbell\AppData\Local\Continuum\anaconda2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#
#                    001A000001PebqoIAB  001A000001WXUIlIAP            0
#                    001A000001WVWWlIAP  001A000001WXUIlIAP            0
#                    001A000001WVcfsIAD  001A000001WXUIlIAP            0
# 001A000001WXUdWIAX 001A000001OhoVIIAZ  001A000001WXUdWIAX            0
#
# [1201994 rows x 4 columns]

# %%
duplicate_candidates.unique_flag.value_counts()
# Out:
# 1    600997
# 0    600997
# Name: unique_flag, dtype: int64

# %%
match_tuples
# Out:
# [('0012K00001XDfP3QAL', '001A00000134Um0IAE'),
#  ('0012K00001XDfP4QAL', '001A00000134hHYIAY'),
#  ('0012K00001XDfP4QAL', '001A00000134hHlIAI'),
#  ('0012K00001XDfP4QAL', '001A00000134hg6IAA'),
#  ('0012K00001XDfP4QAL', '001A00000134hghIAA'),
#  ('0012K00001XDfP4QAL', '001A0000017s1huIAA'),
#  ('0012K00001XDfP4QAL', '001A000001UoXO8IAN'),
#  ('0012K00001XDfP4QAL', '001A000001UoqL4IAJ'),
#  ('0012K00001XDfP6QAL', '001A00000134TyKIAU'),
#  ('0012K00001XDfP6QAL', '001A00000134Us2IAE'),
#  ('0012K00001XDfP6QAL', '001A00000134Y88IAE'),
#  ('0012K00001XDfP6QAL', '001A00000134hjbIAA'),
#  ('0012K00001XDfP6QAL', '001A00000134lURIAY'),
#  ('0012K00001XDfP6QAL', '001A00000134mMzIAI'),
#  ('0012K00001XDfP6QAL', '001A00000134mNWIAY'),
#  ('0012K00001XDfP6QAL', '001A00000134qExIAI'),
#  ('0012K00001XDfP6QAL', '001A00000134rUOIAY'),
#  ('0012K00001XDfP6QAL', '001A00000134tNWIAY'),
#  ('0012K00001XDfP6QAL', '001A00000134utvIAA'),
#  ('0012K00001XDfP6QAL', '001A00000134uu1IAA'),
#  ('0012K00001XDfP6QAL', '001A00000134uu2IAA'),
#  ('0012K00001XDfP6QAL', '001A00000134uu3IAA'),
#  ('0012K00001XDfP6QAL', '001A000001OPLTXIA5'),
#  ('0012K00001XDfP6QAL', '001A000001P5eehIAB'),
#  ('0012K00001XDfP6QAL', '001A000001PebpDIAR'),
#  ('0012K00001XDfP7QAL', '001A00000134Z4TIAU'),
#  ('0012K00001XDfP7QAL', '001A00000134kxDIAQ'),
#  ('0012K00001XDfP7QAL', '001A000001GqULVIA3'),
#  ('0012K00001XDfP7QAL', '001A000001WVcrKIAT'),
#  ('0012K00001XDfP7QAL', '001A000001WVdi5IAD'),
#  ('0012K00001XDfP8QAL', '001A00000134VbGIAU'),
#  ('0012K00001XDfP8QAL', '001A00000134oizIAA'),
#  ('0012K00001XDfP8QAL', '001A000001HNjIDIA1'),
#  ('0012K00001XDfP8QAL', '001A000001PebpDIAR'),
#  ('0012K00001XDfPAQA1', '001A00000134ijGIAQ'),
#  ('0012K00001XDfPAQA1', '001A00000134pEzIAI'),
#  ('0012K00001XDfPAQA1', '001A000001WVWbwIAH'),
#  ('0012K00001XDfPBQA1', '001A00000134TxHIAU'),
#  ('0012K00001XDfPDQA1', '001A00000134n3wIAA'),
#  ('0012K00001XDfPDQA1', '001A00000134uOmIAI'),
#  ('0012K00001XDfPDQA1', '001A00000134uX6IAI'),
#  ('0012K00001XDfPEQA1', '001A00000134ksJIAQ'),
#  ('0012K00001XDfPEQA1', '001A00000134rdPIAQ'),
#  ('0012K00001XDfPFQA1', '001A000001WVdG5IAL'),
#  ('0012K00001XDfPGQA1', '001A00000134UHOIA2'),
#  ('0012K00001XDfPGQA1', '001A00000134nwRIAQ'),
#  ('0012K00001XDfPGQA1', '001A000001PebpDIAR'),
#  ('0012K00001XDf
# 1006644           2  001A000001PeaXmIAJ  001A000001PeaXnIAJ
# 1006649           2  001A000001PeaXnIAJ  001A000001PeaXmIAJ
# 215681           21  001A0000017aa6AIAQ  001A0000017aa68IAA
# 214905           21  001A0000017aa68IAA  001A0000017aa6AIAQ
# 1198151           2  001A000001TSsnSIAT  001A000001WVXeeIAH
#
#                                                 l_org_name  \
# 1011610          AMERICAN SOCIETY FOR DERMATOLOGIC SURGERY
# 1011637           AMERICAN SOCIETY FOR DERMATOLOGIC SURGER
# 934351            NAVY-MARINE CORPS RELIEF SOCIETY-SURVEY1
# 922804             NAVY-MARINE CORPS RELIEF SOCIETY-SURVEY
# 1067533               FLORIDA SOCIETY OF ASSN EXECS-SURVEY
# 1067520              FLORIDA SOCIETY OF ASSN EXECS-SURVEY1
# 1172720                SCHOOL NUTRITION ASSOCIATION-SURVEY
# 1172739               SCHOOL NUTRITION ASSOCIATION-SURVEY1
# 925347                  ALLIANCE OF COMMUNITY HEALTH PLANS
# 920884                   ALLIANCE OF COMMUNITY HEALTH PLAN
# 1006644                 STINSON MORRISON HECKER LLP-BOOKS1
# 1006649                  STINSON MORRISON HECKER LLP-BOOKS
# 215681   NIH/NATIONAL INSTITUTE OF DIABETES & DIGESTIVE...
# 214905   NIH/NATIONAL INSTITUTE OF DIABETES & DIGESTIVE...
# 1198151  IOWA HOMELAND SECURITY AND EMERGENCY MANAGEMEN...
#
#                                                     l_city  \
# 1011610  ROLLING MEADOWS, ROLLING MEADOWS, ROLLING MEAD...
# 1011637                                    ROLLING MEADOWS
# 934351                                           ARLINGTON
# 922804                                           ARLINGTON
# 1067533                                        TALLAHASSEE
# 1067520                                        TALLAHASSEE
# 1172720                                    NATIONAL HARBOR
# 1172739                                    NATIONAL HARBOR
# 925347                                          WASHINGTON
# 920884                                          WASHINGTON
# 1006644                                        KANSAS CITY
# 1006649                                        KANSAS CITY
# 215681                                            BETHESDA
# 214905   BETHESDA, BETHESDA, BETHESDA, BETHESDA, BETHES...
# 1198151                                    WEST DES MOINES
#
#                                                    l_state  \
# 1011610                         IL, IL, IL, IL, IL, IL, IL
# 1011637                                                 IL
# 934351                                                  VA
# 922804                                                  VA
# 1067533                                                 FL
# 1067520                                                 FL
# 1172720                                                 MD
# 1172739                                                 MD
# 925347                                                  DC
# 920884                                                  DC
# 1006644                                                 MO
# 1006649                                                 MO
# 215681                                                  MD
# 214905   MD, MD, MD, MD, MD, MD, MD, MD, MD, MD, MD, MD...
# 1198151                                                 IA
#
#                                              l_postal_code  \
# 1011610    60008, 60008, 60008, 60008, 60008, 60008, 60008
# 1011637                                              60008
# 934351                                               22203
# 922804                                               22203
# 1067533                                              32308
# 1067520                                              32308
# 1172720                                              20745
# 1172739                                              20745
# 925347                                               20006
# 920884                                               20006
# 1006644                                              64106
# 1006649                                              64106
# 215681                                          20892-0001
# 214905   20892-0001, 20892-0001, 20892-0001, 20892-0001...
# 1198151                                              50265
#
#                                                      l_web  \
# 1011610  tcolin@asds.net, rlegoo@asds.net, jkremer@asds...
# 1011637                                     akuhn@asds.net
# 934351                                        hr@nmcrs.org
# 922804                             ann.carpenter@nmcrs.org
# 1067533                                      judy@fsae.org
# 1067520                                    deanna@fsae.org
# 1172720                      pmontague@schoolnutrition.org
# 1172739                      pmontague@schoolnutrition.org
# 925347                                  cmoreschi@achp.org
# 920884                                    mwilson@achp.org
# 1006644                              mejohnson@stinson.com
# 1006649                              dmagariel@stinson.com
# 215681                                 kofac@niddk.nih.gov
# 214905   aretinap@mail.nih.gov, beckleyc@niddk.nih.gov,...
# 1198151                                 l.wessel@mchsi.com
#
#                                                 r_org_name  \
# 1011610           AMERICAN SOCIETY FOR DERMATOLOGIC SURGER
# 1011637          AMERICAN SOCIETY FOR DERMATOLOGIC SURGERY
# 934351             NAVY-MARINE CORPS RELIEF SOCIETY-SURVEY
# 922804            NAVY-MARINE CORPS RELIEF SOCIETY-SURVEY1
# 1067533              FLORIDA SOCIETY OF ASSN EXECS-SURVEY1
# 1067520               FLORIDA SOCIETY OF ASSN EXECS-SURVEY
# 1172720               SCHOOL NUTRITION ASSOCIATION-SURVEY1
# 1172739                SCHOOL NUTRITION ASSOCIATION-SURVEY
# 925347                   ALLIANCE OF COMMUNITY HEALTH PLAN
# 920884                  ALLIANCE OF COMMUNITY HEALTH PLANS
# 1006644                  STINSON MORRISON HECKER LLP-BOOKS
# 1006649                 STINSON MORRISON HECKER LLP-BOOKS1
# 215681   NIH/NATIONAL INSTITUTE OF DIABETES & DIGESTIVE...
# 214905   NIH/NATIONAL INSTITUTE OF DIABETES & DIGESTIVE...
# 1198151  IOWA HOMELAND SECURITY AND EMERGENCY MANAGEMEN...
#
#                                                     r_city  \
# 1011610                                    ROLLING MEADOWS
# 1011637  ROLLING MEADOWS, ROLLING MEADOWS, ROLLING MEAD...
# 934351                                           ARLINGTON
# 922804                                           ARLINGTON
# 1067533                                        TALLAHASSEE
# 1067520                                        TALLAHASSEE
# 1172720                                    NATIONAL HARBOR
# 1172739                                    NATIONAL HARBOR
# 925347                                          WASHINGTON
# 920884                                          WASHINGTON
# 1006644                                        KANSAS CITY
# 1006649                                        KANSAS CITY
# 215681   BETHESDA, BETHESDA, BETHESDA, BETHESDA, BETHES...
# 214905                                            BETHESDA
# 1198151                                    WEST DES MOINES
#
#                                                    r_state  \
# 1011610                                                 IL
# 1011637                         IL, IL, IL, IL, IL, IL, IL
# 934351                                                  VA
# 922804                                                  VA
# 1067533                                                 FL
# 1067520                                                 FL
# 1172720                                                 MD
# 1172739                                                 MD
# 925347                                                  DC
# 920884                                                  DC
# 1006644                                                 MO
# 1006649                                                 MO
# 215681   MD, MD, MD, MD, MD, MD, MD, MD, MD, MD, MD, MD...
# 214905                                                  MD
# 1198151                                                 IA
#
#                                              r_postal_code  \
# 1011610                                              60008
# 1011637    60008, 60008, 60008, 60008, 60008, 60008, 60008
# 934351                                               22203
# 922804                                               22203
# 1067533                                              32308
# 1067520                                              32308
# 1172720                                              20745
# 1172739                                              20745
# 925347                                               20006
# 920884                                               20006
# 1006644                                              64106
# 1006649                                              64106
# 215681   20892-0001, 20892-0001, 20892-0001, 20892-0001...
# 214905                                          20892-0001
# 1198151                                              50265
#
#                                                      r_web  jaro_score  \
# 1011610                                     akuhn@asds.net    0.995122
# 1011637  tcolin@asds.net, rlegoo@asds.net, jkremer@asds...    0.995122
# 934351                             ann.carpenter@nmcrs.org    0.995000
# 922804                                        hr@nmcrs.org    0.995000
# 1067533                                    deanna@fsae.org    0.994595
# 1067520                                      judy@fsae.org    0.994595
# 1172720                      pmontague@schoolnutrition.org    0.994444
# 1172739                      pmontague@schoolnutrition.org    0.994444
# 925347                                    mwilson@achp.org    0.994118
# 920884                                  cmoreschi@achp.org    0.994118
# 1006644                              dmagariel@stinson.com    0.994118
# 1006649                              mejohnson@stinson.com    0.994118
# 215681   aretinap@mail.nih.gov, beckleyc@niddk.nih.gov,...    0.988235
# 214905                                 kofac@niddk.nih.gov    0.988235
# 1198151                                 l.wessel@mchsi.com    0.987097
#
#          fuzz_partial_score  fuzz_sort_score  fuzz_set_score  \
# 1011610                 1.0             0.99            0.99
# 1011637                 1.0             0.99            0.99
# 934351                  1.0             0.99            0.99
# 922804                  1.0             0.99            0.99
# 1067533                 1.0             0.99            0.99
# 1067520                 1.0             0.99            0.99
# 1172720                 1.0             0.99            0.99
# 1172739                 1.0             0.99            0.99
# 925347                  1.0             0.99            0.99
# 920884                  1.0             0.99            0.99
# 1006644                 1.0             0.99            0.99
# 1006649                 1.0             0.99            0.99
# 215681                  1.0             0.98            1.00
# 214905                  1.0             0.98            1.00
# 1198151                 1.0             0.98            1.00
#
#          composite_match_score
# 1011610               2.981341
# 1011637               2.981341
# 934351                2.981250
# 922804                2.981250
# 1067533               2.980946
# 1067520               2.980946
# 1172720               2.980833
# 1172739               2.980833
# 925347                2.980588
# 920884                2.980588
# 1006644               2.980588
# 1006649               2.980588
# 215681                2.976176
# 214905                2.976176
# 1198151               2.975323

# %%
org_matches = full_conc[full_conc.composite_match_score > 2.5]

org_matches.shape
# Out:
# (26572, 18)

# %%
unique_conc = pd.unique(full_conc[['id_l', 'id_r']].values.ravel('K'))

# %%
unique_conc
# Out:
# array(['0012K00001XDfP3QAL', '0012K00001XDfPnQAL', '0012K00001XDfQSQA1',
#        ..., '001A000001WXPDNIA5', '001A000001WXPDOIA5',
#        '001A000001WXPIXIA5'], dtype=object)

# %%
l = [(2,2),(2,3),(1,4),(2,2),(3,2)]
list(set(l))
# Out:
# [(3, 2), (2, 3), (1, 4), (2, 2)]

# %%
l
# Out:
# [(2, 2), (2, 3), (1, 4), (2, 2), (3, 2)]

# %%
b
# Out:
# [(2, 2), (2, 3), (1, 4)]

# %%
unique_flag = []
for tup in l:
    if tup in b:
        unique_flag.append(1)
    else:
        unique_flag.append(0)

unique_flag
# Out:
# [1, 1, 1, 1, 0]

# %%
b = []
seen = set()
for t in l:
    s = tuple(sorted(t))
    if s not in seen:
        seen.add(s)
        b.append(t)

b
# Out:
# [(2, 2), (2, 3), (1, 4)]

# %%
left_df.head()
# Out:
#    0012K00001XE80lQAD Catholic Charities, Diocese of St. Petersburg, Inc.  \
# 0  0012K00001XE80mQAD                                 Carter Agency, Inc
# 1  0012K00001XE80qQAD                            CASCADE COUNTY, MONTANA
# 2  0012K00001XE80rQAD                               Castro & Company LLC
# 3  0012K00001XE80sQAD                  COLUMBIA BASIN HEALTH ASSOCIATION
# 4  0012K00001XE80tQAD                                           CAYO LLC
#
#    Association/Nonprofit            jwayne@ccdosp.org, cmartinez@ccdosp.org  \
# 0  Association/Nonprofit                             dennisc@carteragcy.com
# 1             Local Govt                       bfogerty@cascadecountymt.gov
# 2        Accounting Firm                            rvellocido@castroco.com
# 3  Association/Nonprofit  alvat@cbha.org, lbarbour@cbhc.org, fcornelia@c...
# 4   Construction Company                                        wcs@cayo.us
#
#                       1213 16TH ST N, 1213 16TH ST N  \
# 0                                     208 N MAPLE ST
# 1                               325 2ND AVE N RM 111
# 2                                 1711 KING ST STE C
# 3  140 E MAIN ST, 1410 GRANT ST. STE A301, GEORGE...
# 4                          1400 EVERMAN PKWY STE 127
#
#   SAINT PETERSBURG, SAINT PETERSBURG      FL, FL    33705-1032, 33705-1032  \
# 0                            CRESTON          IA                50801-2361
# 1                        GREAT FALLS          MT                59401-2517
# 2                         ALEXANDRIA          VA                22314-2740
# 3            OTHELLO, DENVER, DENVER  WA, CO, CO  99344-1040, 80203, 80203
# 4                           FT WORTH          TX                76140-5036
#
#                7278931313, 7278931313
# 0                        641-782-8516
# 1                          4064546810
# 2                          7032294440
# 3  5094885256, 3038327594, 3038327594
# 4                          8175686828

# %%
s = pd.DataFrame(['DC', 'MD', 'A'], index=["a", "b", 'c'])
t = pd.DataFrame([20005, 'MD'], index=["a", "b"])

# %%
joined = s.join(t,how='inner',lsuffix='_l',rsuffix='_r')

# %%
joined.head()
# Out:
#   0_l    0_r
# a  DC  20005
# b  MD     MD

# %%
def record_match(left_value,right_value):
    if len(left_value) < 2 or len(right_value) < 2:
        return 0
    if left_value == right_value:
        return 1
    else:
        return 0
    
joined['match'] = joined.apply(lambda x: record_match(x['0_l'], x['0_r']), axis=1)
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-58-48f7d7220db6> in <module>()
#       7         return 0
#       8
# ----> 9 joined['match'] = joined.apply(lambda x: record_match(x['0_l'], x['0_r']), axis=1)
#
# C:\Users\dbell\AppData\Local\Continuum\anaconda2\lib\site-packages\pandas\core\frame.pyc in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6012                          args=args,
#    6013                          kwds=kwds)
# -> 6014         return op.get_result()
#    6015
#    6016     def applymap(self, func):
#
# C:\Users\dbell\AppData\Local\Continuum\anaconda2\lib\site-packages\pandas\core\apply.pyc in get_result(self)
#     140             return self.apply_raw()
#     141
# --> 142         return self.apply_standard()
#     143
#     144     def apply_empty_result(self):
#
# C:\Users\dbell\AppData\Local\Continuum\anaconda2\lib\site-packages\pandas\core\apply.pyc in apply_standard(self)
#     246
#     247         # compute the result using the series generator
# --> 248         self.apply_series_generator()
#     249
#     250         # wrap results
#
# C:\Users\dbell\AppData\Local\Continuum\anaconda2\lib\site-packages\pandas\core\apply.pyc in apply_series_generator(self)
#     275             try:
#     276                 for i, v in enumerate(series_gen):
# --> 277                     results[i] = self.f(v)
#     278                     keys.append(v.name)
#     279             except Exception as e:
#
# <ipython-input-58-48f7d7220db6> in <lambda>(x)
#       7         return 0
#       8
# ----> 9 joined['match'] = joined.apply(lambda x: record_match(x['0_l'], x['0_r']), axis=1)
#
# <ipython-input-58-48f7d7220db6> in record_match(left_value, right_value)
#       1 def record_match(left_value,right_value):
# ----> 2     if len(left_value) < 2 or len(right_value) < 2:
#       3         return 0
#       4     if left_value == right_value:
#       5         return 1
#
# TypeError: ("object of type 'int' has no len()", u'occurred at index a')

# %%
full_conc.to_csv('cupola_org_dup_output.csv')

# %%
full_conc.sort_values(by='id_l')
# Out:
#         id_l count    id_r    id_l  \
# 0                2   49648     101
# 1                2   25788     239
# 2                2   50156     284
# 4                2   85803     284
# 1353             2   54331     321
# 9                2   25905     321
# 8                2   25905     321
# 1352             2   54331     321
# 2698             3   94526     446
# 2696             2   94525     446
# 2700             2   34380     556
# 2702             2   78617     797
# 2701             2   78617     797
# 2703             2   88816     808
# 2704             2   91666     994
# 13               2   25905    1006
# 1355             2   54331    1006
# 1356             2   54331    1006
# 1357             2   54331    1006
# 11               2   25905    1006
# 10               2   25905    1006
# 1354             2   54331    1006
# 12               2   25905    1006
# 2706             2   52504    1193
# 2707             2   13470    1439
# 2708             3   51921    1439
# 2709             2   48970    1441
# 2711             2   70736    1467
# 2710             2   70736    1467
# 2722             2  100564    1512
# ...            ...     ...     ...
# 128024           2  103717  103716
# 128025           2  103716  103717
# 36338            2   78141  103721
# 18446            2    6433  103721
# 18447            2    6433  103721
# 21428            2   11118  103721
# 21429            2   11118  103721
# 24410            2   28337  103721
# 24411            2   28337  103721
# 27392            2   39864  103721
# 27393            2   39864  103721
# 30374            2   39871  103721
# 30375            2   39871  103721
# 33356            2   78134  103721
# 36339            2   78141  103721
# 33357            2   78134  103721
# 55586            2   16962  103722
# 55587            2   16962  103722
# 43284            2   13525  103724
# 43285            2   13525  103724
# 45132            2   13660  103724
# 46980            2   21030  103724
# 46981            2   21030  103724
# 48828            2   21127  103724
# 48829            2   21127  103724
# 50676            2   50443  103724
# 50677            2   50443  103724
# 52524            2   56082  103724
# 52525            2   56082  103724
# 45133            2   13660  103724
#
#                                                l_org_name        l_city  \
# 0                                      Averett University      Danville
# 1                 California State University (Fullerton)     Fullerton
# 2                     Catholic University of America (DC)    Washington
# 4                     Catholic University of America (DC)    Washington
# 1353                           University of Chicago (IL)    Washington
# 9                              University of Chicago (IL)    Washington
# 8                              University of Chicago (IL)    Washington
# 1352                           University of Chicago (IL)    Washington
# 2698                            University of Dayton (OH)        Dayton
# 2696                            University of Dayton (OH)        Dayton
# 2700                                University of Florida   Gainesville
# 2702                           Iowa State University (IA)    Washington
# 2701                           Iowa State University (IA)          Ames
# 2703                   Jacksonville State University (AL)  Jacksonville
# 2704    University of Metropolitan State College of De...        Denver
# 13                              Michigan State University  East Lansing
# 1355                            Michigan State University    Washington
# 1356                            Michigan State University  East Lansing
# 1357                            Michigan State University  East Lansing
# 11                              Michigan State University    Washington
# 10                              Michigan State University    Washington
# 1354                            Michigan State University    Washington
# 12                              Michigan State University  East Lansing
# 2706                          University of Oklahoma (OK)        Norman
# 2707                         Southern Illinois University    Carbondale
# 2708                         Southern Illinois University    Carbondale
# 2709                   Southern Methodist University (TX)        Dallas
# 2711                                  Spring Hill College        Mobile
# 2710                                  Spring Hill College        Mobile
# 2722                          St. Paul School of Theology       Leawood
# ...                                                   ...           ...
# 128024                    Nortek Security & Control, LLC.      Carlsbad
# 128025                           Melrose Industries, PLC.      Carlsbad
# 36338                      5G Everywhere in America, LLC.    Washington
# 18446                      5G Everywhere in America, LLC.    Washington
# 18447                      5G Everywhere in America, LLC.    Washington
# 21428                      5G Everywhere in America, LLC.    Washington
# 21429                      5G Everywhere in America, LLC.    Washington
# 24410                      5G Everywhere in America, LLC.    Washington
# 24411                      5G Everywhere in America, LLC.    Washington
# 27392                      5G Everywhere in America, LLC.    Washington
# 27393                      5G Everywhere in America, LLC.    Washington
# 30374                      5G Everywhere in America, LLC.    Washington
# 30375                      5G Everywhere in America, LLC.    Washington
# 33356                      5G Everywhere in America, LLC.    Washington
# 36339                      5G Everywhere in America, LLC.    Washington
# 33357                      5G Everywhere in America, LLC.    Washington
# 55586                                           Intelstat        McLean
# 55587                                           Intelstat        McLean
# 43284                            Lavie Management Company    Alexandria
# 43285                            Lavie Management Company    Alexandria
# 45132                            Lavie Management Company    Alexandria
# 46980                            Lavie Management Company    Alexandria
# 46981                            Lavie Management Company    Alexandria
# 48828                            Lavie Management Company    Alexandria
# 48829                            Lavie Management Company    Alexandria
# 50676                            Lavie Management Company    Alexandria
# 50677                            Lavie Management Company    Alexandria
# 52524                            Lavie Management Company    Alexandria
# 52525                            Lavie Management Company    Alexandria
# 45133                            Lavie Management Company    Alexandria
#
#        l_state l_postal_code              l_web l_acronym l_alt_name  \
# 0           VA         24541               NULL      NULL       NULL
# 1           CA    92834-9480  www.fullerton.edu      NULL       NULL
# 2           DC         20064       catholic.edu       CUA       NULL
# 4           DC         20064       catholic.edu       CUA       NULL
# 1353        DC         20003   www.uchicago.edu                 NULL
# 9           DC         20003   www.uchicago.edu                 NULL
# 8           DC         20003   www.uchicago.edu                 NULL
# 1352        DC         20003   www.uchicago.edu                 NULL
# 2698        OH         45469        udayton.edu        UD       NULL
# 2696        OH         45469        udayton.edu        UD       NULL
# 2700        FL         32611         www.uf.edu        UF       NULL
# 2702        DC         20001    www.iastate.edu                 NULL
# 2701        IA         50011    www.iastate.edu                 NULL
# 2703        AL         36265        www.jsu.edu                 NULL
# 2704        CO         80217               NULL                 NULL
# 13          MI    48824-1046        www.msu.edu                 NULL
# 1355        DC         20003        www.msu.edu                 NULL
# 1356        MI    48824-1046        www.msu.edu                 NULL
# 1357        MI    48824-1046        www.msu.edu                 NULL
# 11          DC         20003        www.msu.edu                 NULL
# 10          DC         20003        www.msu.edu                 NULL
# 1354        DC         20003        www.msu.edu                 NULL
# 12          MI    48824-1046        www.msu.edu                 NULL
# 2706        OK    73019-0390         www.ou.edu        OU       NULL
# 2707        IL    62901-6899            siu.edu       SIU       NULL
# 2708        IL    62901-6899            siu.edu       SIU       NULL
# 2709        TX         75205               NULL                 NULL
# 2711        AL         36608        www.shc.edu                 NULL
# 2710        AL         36608        www.shc.edu                 NULL
# 2722        KS         66224       WWW.SPST.EDU      SPST       NULL
# ...        ...           ...                ...       ...        ...
# 128024      CA         92010               NULL      NULL       NULL
# 128025      CA         92010               NULL      NULL       NULL
# 36338       DC         20006               NULL      NULL       NULL
# 18446       DC         20006               NULL      NULL       NULL
# 18447       DC         20006               NULL      NULL       NULL
# 21428       DC         20006               NULL      NULL       NULL
# 21429       DC         20006               NULL      NULL       NULL
# 24410       DC         20006               NULL      NULL       NULL
# 24411       DC         20006               NULL      NULL       NULL
# 27392       DC         20006               NULL      NULL       NULL
# 27393       DC         20006               NULL      NULL       NULL
# 30374       DC         20006               NULL      NULL       NULL
# 30375       DC         20006               NULL      NULL       NULL
# 33356       DC         20006               NULL      NULL       NULL
# 36339       DC         20006               NULL      NULL       NULL
# 33357       DC         20006               NULL      NULL       NULL
# 55586       VA         22102               NULL      NULL       NULL
# 55587       VA         22102               NULL      NULL       NULL
# 43284       VA         22314               NULL      NULL       NULL
# 43285       VA         22314               NULL      NULL       NULL
# 45132       VA         22314               NULL      NULL       NULL
# 46980       VA         22314               NULL      NULL       NULL
# 46981       VA         22314               NULL      NULL       NULL
# 48828       VA         22314               NULL      NULL       NULL
# 48829       VA         22314               NULL      NULL       NULL
# 50676       VA         22314               NULL      NULL       NULL
# 50677       VA         22314               NULL      NULL       NULL
# 52524       VA         22314               NULL      NULL       NULL
# 52525       VA         22314               NULL      NULL       NULL
# 45133       VA         22314               NULL      NULL       NULL
#
#                 ...           r_postal_code  \
# 0               ...                   24541
# 1               ...                   92834
# 2               ...                   20064
# 4               ...                 H9S 5J9
# 1353            ...                   20003
# 9               ...                   20003
# 8               ...                   20003
# 1352            ...              20003-1867
# 2698            ...                   45469
# 2696            ...              45469-2316
# 2700            ...                    NULL
# 2702            ...              50011-2031
# 2701            ...              50011-2031
# 2703            ...                   39201
# 2704            ...              80217-3362
# 13              ...                   20003
# 1355            ...                   20003
# 1356            ...              20003-1867
# 1357            ...                   20003
# 11              ...                   20003
# 10              ...                   20003
# 1354            ...              20003-1867
# 12              ...                   20003
# 2706            ...                   73019
# 2707            ...                   20746
# 2708            ...                   62901
# 2709            ...                   75205
# 2711            ...              36608-4545
# 2710            ...                   36608
# 2722            ...                   66224
# ...             ...                     ...
# 128024          ...                   92010
# 128025          ...                   92010
# 36338           ...                   20006
# 18446           ...                   20006
# 18447           ...                   20006
# 21428           ...                   20006
# 21429           ...                   20006
# 24410           ...                   20006
# 24411           ...                   20006
# 27392           ...                   20006
# 27393           ...                   20006
# 30374           ...                   20006
# 30375           ...                   20006
# 33356           ...                   20006
# 36339           ...                   20006
# 33357           ...                   20006
# 55586           ...                   22102
# 55587           ...                   22102
# 43284           ...                   22314
# 43285           ...              22314-3318
# 45132           ...              22314-2862
# 46980           ...                   22314
# 46981           ...                   22314
# 48828           ...                   22314
# 48829           ...                   22314
# 50676           ...              22314-2862
# 50677           ...                   22314
# 52524           ...              22314-1541
# 52525           ...                   22314
# 45133           ...                   22314
#
#                                                     r_web r_acronym  \
# 0           americanhumorstudiesassociation.wordpress.com      AHSA
# 1                                       www.fullerton.edu
# 2                                             cba.cua.edu       CBA
# 4                                             www.cua.org       CUA
# 1353                                            nrcma.org     NRCMA
# 9                                          www.bcanda.com      NULL
# 8                                          www.bcanda.com      NULL
# 1352                                            nrcma.org     NRCMA
# 2698    udayton.edu/business/academics/centers/davisce...   DCPM UD
# 2696    www.udayton.edu/artssciences/academics/mathema...
# 2700                                           www.uf.edu      NULL
# 2702                     www.extension.iastate.edu/isucep   ISUCEP
# 2701                     www.extension.iastate.edu/isucep   ISUCEP
# 2703                                        www.jsums.edu       JSU
# 2704                                            pamla.org    PAMLA
# 13                                         www.bcanda.com      NULL
# 1355                                            nrcma.org     NRCMA
# 1356                                            nrcma.org     NRCMA
# 1357                                            nrcma.org     NRCMA
# 11                                         www.bcanda.com      NULL
# 10                                         www.bcanda.com      NULL
# 1354                                            nrcma.org     NRCMA
# 12                                         www.bcanda.com      NULL
# 2706                                        cmstudies.org      SCMS
# 2707                                        seafarers.org       SIU
# 2708                aih.engr.siu.edu, www.aihydrology.org       AIH
# 2709                                          www.smu.edu       SMU
# 2711                                                 NULL      NULL
# 2710                                                 NULL      NULL
# 2722                                   http://www.cor.org
# ...                                                   ...       ...
# 128024                                               NULL      NULL
# 128025                                               NULL      NULL
# 36338                          tash.org/chapters/nc-tash/   NC-TASH
# 18446                                 www.deutschepost.de      NULL
# 18447                                 www.deutschepost.de      NULL
# 21428                                     www.aapd-dc.org      NULL
# 21429                                     www.aapd-dc.org      NULL
# 24410                             www.stemcellfunding.org      NULL
# 24411                             www.stemcellfunding.org      NULL
# 27392                         www.regionalbonddealers.com      NULL
# 27393                         www.regionalbonddealers.com      NULL
# 30374   www.healthstrategies.net, www.acrpnet.org, www...
# 30375   www.healthstrategies.net, www.acrpnet.org, www...
# 33356                     tash.org/chapters/florida-tash/
# 36339                          tash.org/chapters/nc-tash/   NC-TASH
# 33357                     tash.org/chapters/florida-tash/
# 55586                           www.kidneycarecouncil.org      NULL
# 55587                           www.kidneycarecouncil.org      NULL
# 43284                                            amga.org      AMGA
# 43285                                            amga.org      AMGA
# 45132         amsp.org, epicomm.org/, my.idealliance.org/   EPICOMM
# 46980                                           nccpb.org     NCCPB
# 46981                                           nccpb.org     NCCPB
# 48828                                           amhca.org     AMHCA
# 48829                                           amhca.org     AMHCA
# 50676                                     idealliance.org      IDEA
# 50677                                     idealliance.org      IDEA
# 52524                                        www.vpta.org      VPTA
# 52525                                        www.vpta.org      VPTA
# 45133         amsp.org, epicomm.org/, my.idealliance.org/   EPICOMM
#
#                                                r_alt_name jaro_score  \
# 0                                                    NULL   0.589869
# 1                                                    NULL   0.989744
# 2                                                    NULL   0.624076
# 4                                                    NULL   0.605530
# 1353                                                 NULL   0.448210
# 9                                                    NULL   0.511580
# 8                                                    NULL   0.511580
# 1352                                                 NULL   0.448210
# 2698                                                 NULL   0.840414
# 2696                                                 NULL   0.859304
# 2700                                                 NULL   0.882353
# 2702                                                 NULL   0.847802
# 2701                                                 NULL   0.847802
# 2703                                                 NULL   0.514077
# 2704                                                 NULL   0.517305
# 13                                                   NULL   0.483477
# 1355                                                 NULL   0.518935
# 1356                                                 NULL   0.518935
# 1357                                                 NULL   0.518935
# 11                                                   NULL   0.483477
# 10                                                   NULL   0.483477
# 1354                                                 NULL   0.518935
# 12                                                   NULL   0.483477
# 2706                                                 NULL   0.533179
# 2707                                                 NULL   0.624396
# 2708                                                 NULL   0.561647
# 2709                                                 NULL   0.961905
# 2711                                                 NULL   0.527569
# 2710                                                 NULL   0.527569
# 2722                                                 NULL   0.496439
# ...                                                   ...        ...
# 128024                                               NULL   0.591846
# 128025                                               NULL   0.591846
# 36338                                                NULL   0.526190
# 18446                                                NULL   0.452092
# 18447                                                NULL   0.452092
# 21428                                                NULL   0.455556
# 21429                                                NULL   0.455556
# 24410                                                NULL   0.524603
# 24411                                                NULL   0.524603
# 27392              Regional Bond Dealers Association, The   0.596549
# 27393              Regional Bond Dealers Association, The   0.596549
# 30374                                                NULL   0.477024
# 30375                                                NULL   0.477024
# 33356                                                NULL   0.428042
# 36339                                                NULL   0.526190
# 33357                                                NULL   0.428042
# 55586                                                NULL   0.376812
# 55587                                                NULL   0.376812
# 43284                                                NULL   0.555392
# 43285                                                NULL   0.555392
# 45132   National Association for Printing Leadership, ...   0.456349
# 46980                                                NULL   0.549074
# 46981                                                NULL   0.549074
# 48828                                                NULL   0.568519
# 48829                                                NULL   0.568519
# 50676                                                NULL   0.590009
# 50677                                                NULL   0.590009
# 52524                                                NULL   0.511047
# 52525                                                NULL   0.511047
# 45133   National Association for Printing Leadership, ...   0.456349
#
#        fuzz_partial_score fuzz_sort_score  fuzz_set_score  zip_match  \
# 0                    0.39            0.35            0.35          1
# 1                    0.97            1.00            1.00          1
# 2                    0.55            0.57            0.73          1
# 4                    0.35            0.34            0.34          0
# 1353                 0.35            0.30            0.30          1
# 9                    0.31            0.34            0.34          1
# 8                    0.31            0.34            0.34          1
# 1352                 0.35            0.30            0.30          1
# 2698                 0.84            0.54            0.93          1
# 2696                 0.84            0.64            0.93          1
# 2700                 1.00            0.60            1.00          0
# 2702                 0.85            0.57            0.93          0
# 2701                 0.85            0.57            0.93          1
# 2703                 0.35            0.34            0.35          0
# 2704                 0.36            0.33            0.34          1
# 13                   0.36            0.41            0.41          0
# 1355                 0.44            0.34            0.34          1
# 1356                 0.44            0.34            0.34          0
# 1357                 0.44            0.34            0.34          0
# 11                   0.36            0.41            0.41          1
# 10                   0.36            0.41            0.41          1
# 1354                 0.44            0.34            0.34          1
# 12                   0.36            0.41            0.41          0
# 2706                 0.37            0.33            0.33          1
# 2707                 0.43            0.38            0.38          0
# 2708                 0.36            0.34            0.34          1
# 2709                 0.88            0.90            1.00          1
# 2711                 0.29            0.36            0.36          1
# 2710                 0.29            0.36            0.36          1
# 2722                 0.38            0.42            0.50          1
# ...                   ...             ...             ...        ...
# 128024               0.47            0.37            0.37          1
# 128025               0.47            0.37            0.37          1
# 36338                0.32            0.40            0.40          1
# 18446                0.27            0.26            0.28          1
# 18447                0.27            0.26            0.28          1
# 21428                0.30            0.34            0.34          1
# 21429                0.30            0.34            0.34          1
# 24410                0.37            0.32            0.32          1
# 24411                0.37            0.32            0.32          1
# 27392                0.57            0.47            0.51          1
# 27393                0.57            0.47            0.51          1
# 30374                0.27            0.35            0.35          1
# 30375                0.27            0.35            0.35          1
# 33356                0.29            0.29            0.29          1
# 36339                0.32            0.40            0.40          1
# 33357                0.29            0.29            0.29          1
# 55586                0.33            0.25            0.25          1
# 55587                0.33            0.25            0.25          1
# 43284                0.33            0.38            0.38          1
# 43285                0.33            0.38            0.38          1
# 45132                0.29            0.26            0.26          1
# 46980                0.38            0.35            0.35          1
# 46981                0.38            0.35            0.35          1
# 48828                0.46            0.38            0.38          1
# 48829                0.46            0.38            0.38          1
# 50676                0.33            0.34            0.34          1
# 50677                0.33            0.34            0.34          1
# 52524                0.29            0.33            0.33          1
# 52525                0.29            0.33            0.33          1
# 45133                0.29            0.26            0.26          1
#
#         composite_match_score
# 0                    2.259902
# 1                    3.969808
# 2                    2.855557
# 4                    1.226647
# 1353                 2.048658
# 9                    2.126185
# 8                    2.126185
# 1352                 2.048658
# 2698                 3.362810
# 2696                 3.451978
# 2700                 2.611765
# 2702                 2.398352
# 2701                 3.398352
# 2703                 1.165558
# 2704                 2.160479
# 13                   1.247608
# 1355                 2.229201
# 1356                 1.229201
# 1357                 1.229201
# 11                   2.247608
# 10                   2.247608
# 1354                 2.229201
# 12                   1.247608
# 2706                 2.172384
# 2707                 1.360797
# 2708                 2.201235
# 2709                 3.806429
# 2711                 2.153177
# 2710                 2.153177
# 2722                 2.347329
# ...                       ...
# 128024               2.351384
# 128025               2.351384
# 36338                2.234643
# 18446                1.946569
# 18447                1.946569
# 21428                2.076667
# 21429                2.076667
# 24410                2.150952
# 24411                2.150952
# 27392                2.609912
# 27393                2.609912
# 30374                2.085268
# 30375                2.085268
# 33356                1.973532
# 36339                2.234643
# 33357                1.973532
# 55586                1.905109
# 55587                1.905109
# 43284                2.234044
# 43285                2.234044
# 45132                1.949762
# 46980                2.221806
# 46981                2.221806
# 48828                2.341389
# 48829                2.341389
# 50676                2.200007
# 50677                2.200007
# 52524                2.095785
# 52525                2.095785
# 45133                1.949762
#
# [128026 rows x 23 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np
import pandas as pd

start_time = time.time()
print "CHECKING FOR STATE CODE MATCHES..." #<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<

#example df
d = {'id': [3,6], 'Org_Name': ['Acme Co Inc.', 'Buy Cats Here Inc'], 'Address': ['123 Hammond Lane, Washington, DC', 'Washington, DC 20456']}
left_df = pd.DataFrame(data=d)

#example token dictionary
tokens_dct = {
    'acme':1,
    'co':1,
    'inc':0,
    'buy':1,
    'cats':1,
    'here':1,
    '123':1,
    'hammond':1,
    'lane':0,
    'washington':1,
    'dc':1,
    '20456':1
}

# since you have a predefined vocabulary, you can fix it here
vocabulary = np.array([w for w, b in tokens_dct.items() if b])
cv = CountVectorizer( vocabulary=vocabulary)

frame_list = []
for colname in ['Org_Name', 'Address']:
    tokenmapping = cv.fit_transform(left_df[colname])
    df_row, token_id = tokenmapping.nonzero()

    frame_list.append(pd.DataFrame(np.vstack([vocabulary[token_id], left_df['id'].values[df_row]]).T, columns = ['token', 'id']))

left_keyed = pd.concat(frame_list)

left_keyed

print("name simularity scored --- %s seconds ---" % (time.time() - start_time))
print ""
# Out:
# CHECKING FOR STATE CODE MATCHES...
# name simularity scored --- 0.00300002098083 seconds ---

# %%
vocabulary = np.array([w for w, b in tokens_dct.items() if b ==1])
cv = CountVectorizer( vocabulary=vocabulary)

frame_list = []
for colname in left_tokenized_columns:
    tokenmapping = cv.fit_transform(left_df[colname])
    df_row, token_id = tokenmapping.nonzero()

    frame_list.append(pd.DataFrame(np.vstack([vocabulary[token_id], left_df['id'].values[df_row]]).T, columns = ['token', 'id']))
# Out:
# KeyErrorTraceback (most recent call last)
# <ipython-input-31-e1fb81678ec1> in <module>()
#       7     df_row, token_id = tokenmapping.nonzero()
#       8
# ----> 9     frame_list.append(pd.DataFrame(np.vstack([vocabulary[token_id], left_df['id'].values[df_row]]).T, columns = ['token', 'id']))
#
# C:\Users\Duncan\Anaconda2\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    1962             return self._getitem_multilevel(key)
#    1963         else:
# -> 1964             return self._getitem_column(key)
#    1965
#    1966     def _getitem_column(self, key):
#
# C:\Users\Duncan\Anaconda2\lib\site-packages\pandas\core\frame.pyc in _getitem_column(self, key)
#    1969         # get column
#    1970         if self.columns.is_unique:
# -> 1971             return self._get_item_cache(key)
#    1972
#    1973         # duplicate columns & possible reduce dimensionality
#
# C:\Users\Duncan\Anaconda2\lib\site-packages\pandas\core\generic.pyc in _get_item_cache(self, item)
#    1643         res = cache.get(item)
#    1644         if res is None:
# -> 1645             values = self._data.get(item)
#    1646             res = self._box_item_values(item, values)
#    1647             cache[item] = res
#
# C:\Users\Duncan\Anaconda2\lib\site-packages\pandas\core\internals.pyc in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# C:\Users\Duncan\Anaconda2\lib\site-packages\pandas\core\indexes\base.pyc in get_loc(self, key, method, tolerance)
#    2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
# -> 2444                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2445
#    2446         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'id'

# %%
main_tokens_df['count'].value_counts()
# Out:
# 1    168306
# Name: count, dtype: int64

# %%
unique_tokens_df.flag.value_counts()
# Out:
# 1    19254
# 0     8859
# Name: flag, dtype: int64

# %%
start_time = time.time()
print "LOADING DATAFRAMES INTO MEMORY..."

df = pd.read_csv('RecipientTableUpdated_1.30.19_utf.csv',keep_default_na=False)

#<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#define column names
org_id = 'Recipient_ID'
org_name = 'RecipientName'
org_address1 = 'AddressLine1Txt'
org_city = 'CityNm'
org_state = 'StateAbbreviationCd'
org_zip = 'Zip'
org_web = 'WebsiteAddressTxt'

#set parameters
token_match_min = 2 # minimum number of matched tokens to be considered a match
token_limiter = .9996 # percent of non-single tokens to tokenize, where rare tokens are at the bottom and common at the top
name_weight = .75 #note that this is really .75 * 4 because there are 4 org name simularity metrics
state_weight = 1
zip_weight = 1
phone_weight = 1
composite_score_min = 3.5 #minimum composite match score to be considered a match
#<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<

df.rename(columns={org_id:'id',org_name:'org_name',org_address1:'address1',org_city:'city',org_state:'state',org_zip:'postal_code',org_web:'web'}, inplace=True)

print("dataframes loaded --- %s seconds ---" % (time.time() - start_time))
print ""

start_time = time.time()
print "PRE-PROCESSING: NORMALIZE STATES..."
#normalize state codes
state_lkup = pd.read_csv('state_lkup.csv',keep_default_na=False)

from collections import defaultdict
state_dict = defaultdict(list)
for state, acronym in zip(state_lkup.state.values,state_lkup.acronym.values):
    state_dict[state].append(acronym)

df.state = df.state.str.lower()
df.state = df.state.replace(state_dict)

print("states normalized --- %s seconds ---" % (time.time() - start_time))
print ""

#when you finish pre-processing, this step to split into left and right dataframes:
left_df = df.copy()
left_df.rename(columns={'org_name':'l_org_name','address1':'l_address1','city':'l_city','state':'l_state','postal_code':'l_postal_code','web':'l_web'}, inplace=True)
right_df = df.copy()
right_df.rename(columns={'org_name':'r_org_name','address1':'r_address1','city':'r_city','state':'r_state','postal_code':'r_postal_code','web':'r_web'}, inplace=True)

start_time = time.time()
print "CREATING DICTIONARY OF ALL UNIQUE TOKENS W INCLUDE FLAG..." #<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
   
# for the left dataset
left_tokenized_columns = [
    'l_org_name',
    #'l_acronym',
    #'l_alt_name',
    'l_address1',
    #'l_address2',
    'l_city', 
    'l_state', 
    'l_postal_code',
    'l_web' 
    #'l_phone'
]

# and right
right_tokenized_columns = [
    'r_org_name',
    #'r_acronym',
    #'r_alt_name',
    'r_address1',
    #'r_address2',
    'r_city', 
    'r_state', 
    'r_postal_code',
    'r_web' 
    #'r_phone'
]

# lowercase the name and split on spaces, remove non-alphanumeric chars
def tokenize_name(name):
    if isinstance(name, basestring) is True:
        clean_name = ''.join(c if c.isalnum() else ' ' for c in name)
        return clean_name.lower().split()
    else:
        return name

unique_tokens = [] #we treat state and zips differently because we want to include ALl state and zip tokens as these are unique

#<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<< add chosen unique columns here from each df
for word in left_df['l_state']:
    if isinstance(word, float) is False:
        unique_tokens.append(tokenize_name(str(word)))

for word in left_df['l_postal_code']:
    if isinstance(word, float) is False:
        unique_tokens.append(tokenize_name(str(word)))

#for word in left_df['l_acronym']:
#    if isinstance(word, float) is False:
#        unique_tokens.append(tokenize_name(str(word)))

#for word in left_df['l_phone']:
#    if isinstance(word, float) is False:
#        unique_tokens.append(tokenize_name(str(word)))
#<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
        
unique_flat_list = [item for sublist in unique_tokens for item in sublist]

#instantiate counter and use to count word frequencies in flat list
u_cnt = Counter()
for token in unique_flat_list:
    u_cnt[token] += 1
    
u_cnt_dict = dict(u_cnt) #convert to dictionary

unique_tokens_df = pd.DataFrame(u_cnt_dict.items(), columns=['token', 'count'])
unique_tokens_df = unique_tokens_df.sort_values(by='count')  #sorting by count so that we can take the first x% of tokens by rare frequency

unique_token_flag = []
for index, value in enumerate(unique_tokens_df['count']):
    if value == 1:
        unique_token_flag.append(0)  #for any tokens occuring only once, we exclude
    else:
        unique_token_flag.append(1)

unique_tokens_df['flag'] = unique_token_flag        
        
all_other_words = [] #creating a list of all words used in just ONE of the dfs in selected columns, for counting to determine rarity

for word in left_df['l_org_name']:
    if isinstance(word, float) is False:
        all_other_words.append(tokenize_name(str(word)))

#for word in left_df['l_alt_name']:
#    if isinstance(word, float) is False:
#        all_other_words.append(tokenize_name(str(word)))

for word in left_df['l_address1']:
    if isinstance(word, float) is False:
        all_other_words.append(tokenize_name(str(word)))

for word in left_df['l_city']:
    if isinstance(word, float) is False:
        all_other_words.append(tokenize_name(str(word)))

for word in left_df['l_web']:
    if isinstance(word, float) is False:
        all_other_words.append(tokenize_name(str(word)))
    
flat_list = [item for sublist in all_other_words for item in sublist] #flatten list so it can be counted
#new_tokens = list(set(flat_list) - set(unique_flat_list)) #getting a list of tokens which are NOT included in the first flat_list

#instantiate counter and use to count word frequencies in flat list
cnt = Counter()
for token in flat_list:
    cnt[token] += 1
    
cnt_dict = dict(cnt) #convert to dictionary

main_tokens_df = pd.DataFrame(cnt_dict.items(), columns=['token', 'count'])
main_tokens_df = main_tokens_df.sort_values(by='count')  #sorting by count so that we can take the first x% of tokens by rare frequency

main_token_flag = []
for index, value in enumerate(main_tokens_df['count']):
    if value == 1:
        main_token_flag.append(0)  #for any tokens occuring only once, we exclude
    elif index < int(main_tokens_df.shape[0] * token_limiter): #important line, we are cutting the top x% of frequently occuring tokens
        main_token_flag.append(1)
    else:
        main_token_flag.append(0)  #for the most common tokens, we exclude

main_tokens_df['flag'] = main_token_flag

all_tokens = pd.concat([unique_tokens_df, main_tokens_df])

all_tokens.drop('count',axis=1,inplace=True)
all_tokens['flag'] = all_tokens.flag.astype(int) #converting flags to int
tokens_dct = all_tokens.to_dict('split') #converting tokens_df to dictionary
tokens_dct=dict(tokens_dct['data']) #honestly can't remember why this works, something to do with conversion to dictionary

print("token dictionary created --- %s seconds ---" % (time.time() - start_time))
print ""
                           
start_time = time.time()
print "TOKENIZING LEFT DATAFRAME..." #<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<

#NOTE: tokenizing the dataframes is the most computationally expensive part of this script.  

#tokenize left dataframe
vocabulary = np.array([w for w, b in tokens_dct.items() if b ==1]) #this works even without the ==1 and I don't know why
cv = CountVectorizer( vocabulary=vocabulary)

frame_list = []
for colname in left_tokenized_columns:
    tokenmapping = cv.fit_transform(left_df[colname])
    df_row, token_id = tokenmapping.nonzero()

    frame_list.append(pd.DataFrame(np.vstack([vocabulary[token_id], left_df['id'].values[df_row]]).T, columns = ['token', 'id']))

left_keyed = pd.concat(frame_list)
    
print("left dataframe tokenized --- %s seconds ---" % (time.time() - start_time))
print ""

start_time = time.time()
print "TOKENIZING RIGHT DATAFRAME..." #<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<

#tokenize right dataframe
right_keyed = left_keyed.copy()
    
print("right dataframe tokenized --- %s seconds ---" % (time.time() - start_time))
print ""

start_time = time.time()
print "JOINING LEFT & RIGHT TOKEN KEYS..." #<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<

#join left and right token keys
left_keyed.set_index('token',inplace=True)
right_keyed.set_index('token',inplace=True)
joined = left_keyed.join(right_keyed, how='inner',lsuffix='_l',rsuffix='_r')

print("left & right token keys joined --- %s seconds ---" % (time.time() - start_time))
print ""

start_time = time.time()
print "GROUPING BY UNIQUE LEFT & RIGHT IDS & GETTING COUNT OF MATCHED TOKENS..." #<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<

#aggregate to get a count of unique id_l and id_r pairs based on joined tokens, which is used to assess match strength
aggregations = {
    'id_l': 'count'
}

keys_grouped = joined.groupby(by=['id_l', 'id_r']).agg(aggregations)
keys_grouped.rename(columns={'id_l':'id_l count'}, inplace=True)

print("keys grouped & counted --- %s seconds ---" % (time.time() - start_time))
print ""

start_time = time.time()
print "REDUCING DOWN TO SUFFICIENT MATCHES..." #<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<

#here we are reducing down to those match candidates which meet the minimum threshold of matched tokens
#and crucially, we are excluding any matches to SELF
matched_records = keys_grouped[keys_grouped['id_l count'] >= token_match_min]

#adding a column for the id_r values, which are initially excluded becuase we are merging using the id_l
right_ids = matched_records.index.get_level_values('id_r')
matched_records['id_r'] = right_ids

#adding left Ids because I think we need them, probably a way to check index but meh
left_ids = matched_records.index.get_level_values('id_l')
matched_records['id_l'] = left_ids

duplicate_candidates = matched_records[matched_records['id_l'] <> matched_records['id_r']]

print("matches reduced --- %s seconds ---" % (time.time() - start_time))
print ""

start_time = time.time()
print "CONCATENATING MATCH IDS WITH ORIGINAL DATA..." #<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<

#renaming ids to be linked to source.  this happens here and not the beginning so as to play nice with the prepare join keys generator
left_df.rename(columns={'id':'id_l'}, inplace=True)
right_df.rename(columns={'id':'id_r'}, inplace=True)

#creating left/right dataframes which contain only the most relevant details for reviewing the match strengths
left_match_data = left_df[['id_l','l_org_name','l_city','l_state','l_postal_code','l_web']].copy()
right_match_data = right_df[['id_r','r_org_name','r_city','r_state','r_postal_code','r_web']].copy()

#making sure keys are str, results in blank df otherwise
left_match_data.id_l = left_match_data.id_l.astype('str')
right_match_data.id_r = right_match_data.id_r.astype('str')
duplicate_candidates.id_l = duplicate_candidates.id_l.astype('str')
duplicate_candidates.id_r = duplicate_candidates.id_r.astype('str')

#merging matched_records df with original record data for ease of review
l_conc = pd.merge(duplicate_candidates, left_match_data, on='id_l')
full_conc = pd.merge(l_conc, right_match_data, on='id_r')
# Out:
# LOADING DATAFRAMES INTO MEMORY...
# dataframes loaded --- 0.72200012207 seconds ---
#
# PRE-PROCESSING: NORMALIZE STATES...
# states normalized --- 2.17199993134 seconds ---
#
# CREATING DICTIONARY OF ALL UNIQUE TOKENS W INCLUDE FLAG...
# token dictionary created --- 8.1890001297 seconds ---
#
# TOKENIZING LEFT DATAFRAME...
# left dataframe tokenized --- 8.12400007248 seconds ---
#
# TOKENIZING RIGHT DATAFRAME...
# right dataframe tokenized --- 0.0279998779297 seconds ---
#
# JOINING LEFT & RIGHT TOKEN KEYS...
# MemoryErrorTraceback (most recent call last)
# <ipython-input-78-c34b688936fe> in <module>()
#     223 left_keyed.set_index('token',inplace=True)
#     224 right_keyed.set_index('token',inplace=True)
# --> 225 joined = left_keyed.join(right_keyed, how='inner',lsuffix='_l',rsuffix='_r')
#     226
#     227 print("left & right token keys joined --- %s seconds ---" % (time.time() - start_time))
#
# C:\Users\Duncan\Anaconda2\lib\site-packages\pandas\core\frame.pyc in join(self, other, on, how, lsuffix, rsuffix, sort)
#    4667         # For SparseDataFrame's benefit
#    4668         return self._join_compat(other, on=on, how=how, lsuffix=lsuffix,
# -> 4669                                  rsuffix=rsuffix, sort=sort)
#    4670
#    4671     def _join_compat(self, other, on=None, how='left', lsuffix='', rsuffix='',
#
# C:\Users\Duncan\Anaconda2\lib\site-packages\pandas\core\frame.pyc in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    4682             return merge(self, other, left_on=on, how=how,
#    4683                          left_index=on is None, right_index=True,
# -> 4684                          suffixes=(lsuffix, rsuffix), sort=sort)
#    4685         else:
#    4686             if on is not None:
#
# C:\Users\Duncan\Anaconda2\lib\site-packages\pandas\core\reshape\merge.pyc in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator)
#      52                          right_index=right_index, sort=sort, suffixes=suffixes,
#      53                          copy=copy, indicator=indicator)
# ---> 54     return op.get_result()
#      55
#      56
#
# C:\Users\Duncan\Anaconda2\lib\site-packages\pandas\core\reshape\merge.pyc in get_result(self)
#     567                 self.left, self.right)
#     568
# --> 569         join_index, left_indexer, right_indexer = self._get_join_info()
#     570
#     571         ldata, rdata = self.left._data, self.right._data
#
# C:\Users\Duncan\Anaconda2\lib\site-packages\pandas\core\reshape\merge.pyc in _get_join_info(self)
#     720             join_index, left_indexer, right_indexer = \
#     721                 left_ax.join(right_ax, how=self.how, return_indexers=True,
# --> 722                              sort=self.sort)
#     723         elif self.right_index and self.how == 'left':
#     724             join_index, left_indexer, right_indexer = \
#
# C:\Users\Duncan\Anaconda2\lib\site-packages\pandas\core\indexes\base.pyc in join(self, other, how, level, return_indexers, sort)
#    3037         if not self.is_unique and not other.is_unique:
#    3038             return self._join_non_unique(other, how=how,
# -> 3039                                          return_indexers=return_indexers)
#    3040         elif not self.is_unique or not other.is_unique:
#    3041             if self.is_monotonic and other.is_monotonic:
#
# C:\Users\Duncan\Anaconda2\lib\site-packages\pandas\core\indexes\base.pyc in _join_non_unique(self, other, how, return_indexers)
#    3125         left_idx, right_idx = _get_join_indexers([self.values],
#    3126                                                  [other._values], how=how,
# -> 3127                                                  sort=True)
#    3128
#    3129         left_idx = _ensure_platform_int(left_idx)
#
# C:\Users\Duncan\Anaconda2\lib\site-packages\pandas\core\reshape\merge.pyc in _get_join_indexers(left_keys, right_keys, sort, how, **kwargs)
#     996     join_func = _join_functions[how]
#     997
# --> 998     return join_func(lkey, rkey, count, **kwargs)
#     999
#    1000
#
# pandas\_libs\join.pyx in pandas._libs.join.inner_join()
#
# pandas\_libs\join.pyx in pandas._libs.join._get_result_indexer()
#
# C:\Users\Duncan\Anaconda2\lib\site-packages\pandas\core\algorithms.pyc in take_nd(arr, indexer, axis, out, fill_value, mask_info, allow_fill)
#    1463             # (s.t. df.values is c-contiguous and df._data.blocks[0] is its
#    1464             # f-contiguous transpose)
# -> 1465             out = np.empty(out_shape, dtype=dtype, order='F')
#    1466         else:
#    1467             out = np.empty(out_shape, dtype=dtype)
#
# MemoryError:

# %%
left_keyed.set_index('token',inplace=True)
left_keyed[left_keyed.id =='1']
# Out:
# KeyErrorTraceback (most recent call last)
# <ipython-input-77-5565b89f61a4> in <module>()
# ----> 1 left_keyed.set_index('token',inplace=True)
#       2 left_keyed[left_keyed.id =='1']
#
# C:\Users\Duncan\Anaconda2\lib\site-packages\pandas\core\frame.pyc in set_index(self, keys, drop, append, inplace, verify_integrity)
#    2828                 names.append(None)
#    2829             else:
# -> 2830                 level = frame[col]._values
#    2831                 names.append(col)
#    2832                 if drop:
#
# C:\Users\Duncan\Anaconda2\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    1962             return self._getitem_multilevel(key)
#    1963         else:
# -> 1964             return self._getitem_column(key)
#    1965
#    1966     def _getitem_column(self, key):
#
# C:\Users\Duncan\Anaconda2\lib\site-packages\pandas\core\frame.pyc in _getitem_column(self, key)
#    1969         # get column
#    1970         if self.columns.is_unique:
# -> 1971             return self._get_item_cache(key)
#    1972
#    1973         # duplicate columns & possible reduce dimensionality
#
# C:\Users\Duncan\Anaconda2\lib\site-packages\pandas\core\generic.pyc in _get_item_cache(self, item)
#    1643         res = cache.get(item)
#    1644         if res is None:
# -> 1645             values = self._data.get(item)
#    1646             res = self._box_item_values(item, values)
#    1647             cache[item] = res
#
# C:\Users\Duncan\Anaconda2\lib\site-packages\pandas\core\internals.pyc in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# C:\Users\Duncan\Anaconda2\lib\site-packages\pandas\core\indexes\base.pyc in get_loc(self, key, method, tolerance)
#    2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
# -> 2444                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2445
#    2446         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'token'

# %%
joined = left_keyed.join(right_keyed, how='inner',lsuffix='_l',rsuffix='_r')

print("left & right token keys joined --- %s seconds ---" % (time.time() - start_time))
print ""

start_time = time.time()
print "GROUPING BY UNIQUE LEFT & RIGHT IDS & GETTING COUNT OF MATCHED TOKENS..." #<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<

#aggregate to get a count of unique id_l and id_r pairs based on joined tokens, which is used to assess match strength
aggregations = {
    'id_l': 'count'
}

keys_grouped = joined.groupby(by=['id_l', 'id_r']).agg(aggregations)
keys_grouped.rename(columns={'id_l':'id_l count'}, inplace=True)

print("keys grouped & counted --- %s seconds ---" % (time.time() - start_time))
print ""

start_time = time.time()
print "REDUCING DOWN TO SUFFICIENT MATCHES..." #<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<

#here we are reducing down to those match candidates which meet the minimum threshold of matched tokens
#and crucially, we are excluding any matches to SELF
matched_records = keys_grouped[keys_grouped['id_l count'] >= token_match_min]
# Out:
# (1637244, 2)

# %%
joined[joined.token_l == 'cingular']
# Out:
#        token_l  id_l  token_id_l     token_r   id_r  token_id_r
# 6224  cingular  2733       47627    cingular   2733       47627
# 6224  cingular  2733       47627          us   2921       23234
# 6224  cingular  2733       47627  harrisburg   5656       55512
# 6224  cingular  2733       47627          ia   6417       16433
# 6224  cingular  2733       47627       99501   7211        2273
# 6224  cingular  2733       47627  archeworks  28487      136556
# 6226  cingular  2734       47627    cingular   2734       47627
# 6226  cingular  2734       47627   marquette   2922      153399
# 6226  cingular  2734       47627      dallas   5658       83591
# 6226  cingular  2734       47627          sd   6419      109385
# 6226  cingular  2734       47627       99155   7215       11153
# 6226  cingular  2734       47627       https  28496       63120

# %%
left_keyed
# Out:
#                      token      id  token_id
# 0                      501       1     30381
# 1                  commons       1     81204
# 2                     leaf       2    130163
# 3                   womans       3    150776
# 4                    place       3    161424
# 5                     aarp       4     86367
# 6                     aarp       5     86367
# 7                 hospital       6    116892
# 8                    abbot       6    152281
# 9             northwestern       6    154354
# 10                  abbott       7       275
# 11                   house       7    126458
# 12               christian       8     76427
# 13                 abilene       8     49334
# 14                 ability       9     12153
# 15                 ability      10     12153
# 16                  counts      10    146827
# 17                      ac      11     11835
# 18                portland      11     93680
# 19                 academy      12     40231
# 20                    arts      13     17042
# 21                 academy      13     40231
# 22                sciences      13      8887
# 23                 academy      14     40231
# 24                    prep      14     52446
# 25                   tampa      14     84113
# 26                    acca      15    106726
# 27                  access      16     49794
# 28                  access      17     49794
# 29                 network      17    126232
# ...                    ...     ...       ...
# 45710                  edu  237763     31239
# 45711             wvstateu  237763     29051
# 45712                  tri  237771     66500
# 45713        theclaycenter  237772    121988
# 45714                 pets  237782    114428
# 45715                 rchs  237782    154421
# 45716                  edu  237793     31239
# 45717               alumni  237793    111598
# 45718                 rccr  237797     73087
# 45719                youth  237804     82901
# 45720                wvpca  237811    126165
# 45721               patton  237812    104568
# 45722                craik  237812    167117
# 45723            hospitals  237817     25285
# 45724                about  237817     72583
# 45725                  wvu  237817     87630
# 45726       carnegiehallwv  237819     77255
# 45727      youthleadership  237828     15375
# 45728                  yla  237828    162464
# 45729                shack  237829    157093
# 45730    educationalliance  237831     62300
# 45731                 nysf  237832     34770
# 45732            changeinc  237833    110124
# 45733                 sals  237844     32910
# 45734                 info  237844     48712
# 45735                 ovmc  237847     85849
# 45736  youthservicessystem  237869     59122
# 45737                  net  237879     58888
# 45738              daymark  237887      4202
# 45739         wvhumanities  237891    157212
#
# [1637244 rows x 3 columns]
